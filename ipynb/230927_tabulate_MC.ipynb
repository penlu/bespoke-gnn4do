# %%
# %load_ext autoreload
# %autoreload 2

import os
import json
import pandas as pd
import numpy as np
import sys
from pathlib import Path

root_folder = Path('/home/bcjexu/maxcut-80/bespoke-gnn4do/')
sys.path.insert(0, str(root_folder))

from utils.tabulate import load_datasets, load_train_outputs, load_baseline_outputs

# %%
baseline_folders = ['baseline_runs/230927_snapshot', 'baseline_runs/230927_snapshot2']
baseline_folders = ['baseline_runs/230928_gurobi']
baseline_folders_greedy = ['baseline_runs/230928_greedy']

# %%
# load datasets and calculate validation slices
import torch

datasets = load_datasets()
indices = {}
for name, dataset in datasets.items():
    torch.manual_seed(0)
    print(f"{name} dataset size: {len(dataset)}")
    train_size = int(0.8 * len(dataset))
    val_size = (len(dataset) - train_size)//2
    test_size = len(dataset) - train_size - val_size
    _, _, test_dataset = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])
    indices[name] = test_dataset.indices

dataset_names = list(datasets.keys())
#dataset_names.append('RANDOM')
#dataset_names.append('RANDOM 500')
dataset_names.append('ForcedRB')
# Out:
# loading PROTEINS
# loading ENZYMES
# loading COLLAB
# loading IMDB-BINARY
# loading MUTAG
# PROTEINS dataset size: 1113
# ENZYMES dataset size: 600
# COLLAB dataset size: 5000
# IMDB-BINARY dataset size: 1000
# MUTAG dataset size: 188

# %%
# loading max cut results from files

print("loading model losses")
maxcut_models = load_train_outputs(root_folder / 'training_runs', '230823_test')
print("loading sdp lift losses")
maxcut_sdp_lift = load_baseline_outputs(root_folder / 'baseline_runs', '230824_sdp', 'sdp', indices)
print("loading sdp proj losses")
maxcut_sdp_proj = load_baseline_outputs(root_folder / 'baseline_runs', '230824_sdp', 'sdp|random_hyperplane', indices)
# Out:
# loading model losses
# loading sdp lift losses
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY sdp: 97.83850940704346
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM sdp: 896.5637869873046
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB sdp: 2627.7631793823243
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS sdp: 103.8618523819106
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG sdp: 28.101939753482217
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES sdp: 82.51778809229533
# loading sdp proj losses
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY sdp|random_hyperplane: 97.495
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM sdp|random_hyperplane: 872.0625
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB sdp|random_hyperplane: 2624.261
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS sdp|random_hyperplane: 102.29910714285714
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG sdp|random_hyperplane: 27.94736842105263
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES sdp|random_hyperplane: 81.45

# %%
# read in files

vc_scores = pd.DataFrame()

for baseline_folder in baseline_folders:
    for model_folder in os.listdir(os.path.join(root_folder, baseline_folder)):
        with open(os.path.join(os.path.join(root_folder, baseline_folder, model_folder), 'params.txt'), 'r') as f:
            model_args = json.load(f)
        if model_args['problem_type'] != 'max_cut':
            continue
        
        #print(model_args['gurobi'], model_args['gurobi_timeout'], model_args['dataset'], model_args['gen_n'])
        #print(load_baseline_outputs(Path(os.path.join(root_folder, baseline_folder)), model_folder, 'gurobi', indices))
        row = f'gurobi_{model_args["gurobi_timeout"]}'
        if isinstance(model_args['gen_n'], list):
            col = f"{model_args['dataset']}@@{model_args['gen_n'][0]}"
        else:
            col = f"{model_args['dataset']}"
        print(row,col)

        val = load_baseline_outputs(Path(os.path.join(root_folder, baseline_folder)), model_folder, 'gurobi') # indices)
        
        vc_scores.at[ row , col] = list(val.values())[0]
        #vc_scores.at[ row , 'gen_n'] = model_args['gen_n']
        #vc_scores.at[ row , ''] = model_args['gen_n']
# Out:
# gurobi_2.0 PROTEINS
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS gurobi: 102.36160714285714
# gurobi_8.0 COLLAB
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB gurobi: 2624.617
# gurobi_0.1 WattsStrogatz@@50
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 198.744
# gurobi_0.1 REDDIT-BINARY
# load_baseline_outputs: REDDIT-BINARY length: 100
# load_baseline_outputs: REDDIT-BINARY gurobi: 693.015
# gurobi_4.0 ErdosRenyi@@400
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 16495.059
# gurobi_8.0 PROTEINS
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS gurobi: 102.36160714285714
# gurobi_4.0 PowerlawCluster@@100
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 712.6245
# gurobi_0.5 PowerlawCluster@@400
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 2169.456
# gurobi_4.0 ENZYMES
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES gurobi: 81.45
# gurobi_0.5 REDDIT-BINARY
# load_baseline_outputs: REDDIT-BINARY length: 100
# load_baseline_outputs: REDDIT-BINARY gurobi: 694.075
# gurobi_4.0 WattsStrogatz@@100
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 392.068
# gurobi_0.1 WattsStrogatz@@400
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 1173.45
# gurobi_2.0 MUTAG
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG gurobi: 27.94736842105263
# gurobi_0.1 PROTEINS
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS gurobi: 102.28125
# gurobi_0.1 ErdosRenyi@@50
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 529.931
# gurobi_4.0 ErdosRenyi@@100
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 2002.8975
# gurobi_0.1 PowerlawCluster@@100
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 711.6795
# gurobi_8.0 ErdosRenyi@@100
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 2002.9315
# gurobi_2.0 BarabasiAlbert@@50
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 352.121
# gurobi_8.0 WattsStrogatz@@400
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 1179.861
# gurobi_0.5 PowerlawCluster@@50
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 346.423
# gurobi_1.0 BarabasiAlbert@@100
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 719.718
# gurobi_0.1 REDDIT-MULTI-5K
# load_baseline_outputs: REDDIT-MULTI-5K length: 100
# load_baseline_outputs: REDDIT-MULTI-5K gurobi: 785.445
# gurobi_0.5 ErdosRenyi@@100
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 2002.8815
# gurobi_2.0 REDDIT-MULTI-5K
# load_baseline_outputs: REDDIT-MULTI-5K length: 100
# load_baseline_outputs: REDDIT-MULTI-5K gurobi: 787.915
# gurobi_8.0 WattsStrogatz@@100
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 392.068
# gurobi_0.1 IMDB-BINARY
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY gurobi: 97.495
# gurobi_4.0 PROTEINS
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS gurobi: 102.36160714285714
# gurobi_8.0 REDDIT-MULTI-12K
# load_baseline_outputs: REDDIT-MULTI-12K length: 100
# load_baseline_outputs: REDDIT-MULTI-12K gurobi: 568.94
# gurobi_4.0 BarabasiAlbert@@100
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 719.891
# gurobi_8.0 REDDIT-BINARY
# load_baseline_outputs: REDDIT-BINARY length: 100
# load_baseline_outputs: REDDIT-BINARY gurobi: 694.135
# gurobi_0.5 ENZYMES
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES gurobi: 81.45
# gurobi_1.0 BarabasiAlbert@@400
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 2208.112
# gurobi_2.0 PowerlawCluster@@400
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 2169.86
# gurobi_0.5 WattsStrogatz@@100
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 392.058
# gurobi_1.0 WattsStrogatz@@100
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 392.067
# gurobi_1.0 WattsStrogatz@@50
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 198.745
# gurobi_1.0 PowerlawCluster@@400
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 2169.458
# gurobi_4.0 PowerlawCluster@@400
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 2173.765
# gurobi_2.0 REDDIT-BINARY
# load_baseline_outputs: REDDIT-BINARY length: 100
# load_baseline_outputs: REDDIT-BINARY gurobi: 694.135
# gurobi_2.0 ErdosRenyi@@400
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 16494.352
# gurobi_2.0 WattsStrogatz@@400
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 1177.892
# gurobi_4.0 REDDIT-BINARY
# load_baseline_outputs: REDDIT-BINARY length: 100
# load_baseline_outputs: REDDIT-BINARY gurobi: 694.135
# gurobi_0.1 PowerlawCluster@@400
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 2169.456
# gurobi_8.0 MUTAG
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG gurobi: 27.94736842105263
# gurobi_0.1 PowerlawCluster@@50
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 346.177
# gurobi_0.5 ErdosRenyi@@50
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 529.977
# gurobi_0.5 BarabasiAlbert@@50
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 352.105
# gurobi_0.5 ErdosRenyi@@400
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 16481.573
# gurobi_0.5 REDDIT-MULTI-12K
# load_baseline_outputs: REDDIT-MULTI-12K length: 100
# load_baseline_outputs: REDDIT-MULTI-12K gurobi: 568.76
# gurobi_0.1 ENZYMES
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES gurobi: 81.45
# gurobi_0.5 PowerlawCluster@@100
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 711.8785
# gurobi_0.1 COLLAB
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB gurobi: 2624.321
# gurobi_1.0 REDDIT-BINARY
# load_baseline_outputs: REDDIT-BINARY length: 100
# load_baseline_outputs: REDDIT-BINARY gurobi: 694.105
# gurobi_4.0 REDDIT-MULTI-5K
# load_baseline_outputs: REDDIT-MULTI-5K length: 100
# load_baseline_outputs: REDDIT-MULTI-5K gurobi: 787.915
# gurobi_2.0 ENZYMES
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES gurobi: 81.45
# gurobi_0.1 REDDIT-MULTI-12K
# load_baseline_outputs: REDDIT-MULTI-12K length: 100
# load_baseline_outputs: REDDIT-MULTI-12K gurobi: 567.71
# gurobi_2.0 PowerlawCluster@@100
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 712.4625
# gurobi_0.5 COLLAB
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB gurobi: 2624.511
# gurobi_0.1 ErdosRenyi@@100
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 2002.8815
# gurobi_2.0 PowerlawCluster@@50
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 346.424
# gurobi_1.0 COLLAB
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB gurobi: 2624.569
# gurobi_1.0 ENZYMES
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES gurobi: 81.45
# gurobi_1.0 MUTAG
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG gurobi: 27.94736842105263
# gurobi_2.0 IMDB-BINARY
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY gurobi: 97.495
# gurobi_0.5 IMDB-BINARY
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY gurobi: 97.495
# gurobi_1.0 ErdosRenyi@@50
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 530.026
# gurobi_4.0 MUTAG
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG gurobi: 27.94736842105263
# gurobi_8.0 BarabasiAlbert@@100
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 720.172
# gurobi_0.1 BarabasiAlbert@@400
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 2208.111
# gurobi_0.5 REDDIT-MULTI-5K
# load_baseline_outputs: REDDIT-MULTI-5K length: 100
# load_baseline_outputs: REDDIT-MULTI-5K gurobi: 787.135
# gurobi_8.0 PowerlawCluster@@100
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 712.8815
# gurobi_0.1 WattsStrogatz@@100
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 390.957
# gurobi_8.0 REDDIT-MULTI-5K
# load_baseline_outputs: REDDIT-MULTI-5K length: 100
# load_baseline_outputs: REDDIT-MULTI-5K gurobi: 787.915
# gurobi_1.0 ErdosRenyi@@100
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 2002.8815
# gurobi_2.0 COLLAB
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB gurobi: 2624.595
# gurobi_1.0 REDDIT-MULTI-5K
# load_baseline_outputs: REDDIT-MULTI-5K length: 100
# load_baseline_outputs: REDDIT-MULTI-5K gurobi: 787.485
# gurobi_8.0 BarabasiAlbert@@400
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 2212.489
# gurobi_2.0 WattsStrogatz@@50
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 198.745
# gurobi_2.0 ErdosRenyi@@50
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 530.076
# gurobi_2.0 BarabasiAlbert@@400
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 2208.624
# gurobi_1.0 BarabasiAlbert@@50
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 352.116
# gurobi_2.0 WattsStrogatz@@100
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 392.068
# gurobi_0.1 MUTAG
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG gurobi: 27.94736842105263
# gurobi_4.0 WattsStrogatz@@50
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 198.745
# gurobi_0.5 BarabasiAlbert@@400
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 2208.111
# gurobi_1.0 PROTEINS
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS gurobi: 102.36160714285714
# gurobi_8.0 IMDB-BINARY
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY gurobi: 97.495
# gurobi_4.0 WattsStrogatz@@400
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 1178.477
# gurobi_2.0 REDDIT-MULTI-12K
# load_baseline_outputs: REDDIT-MULTI-12K length: 100
# load_baseline_outputs: REDDIT-MULTI-12K gurobi: 568.91
# gurobi_1.0 PowerlawCluster@@100
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 712.2625
# gurobi_2.0 ErdosRenyi@@100
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 2002.8825
# gurobi_0.1 BarabasiAlbert@@50
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 351.872
# gurobi_8.0 BarabasiAlbert@@50
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 352.121
# gurobi_8.0 ErdosRenyi@@400
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 16495.307
# gurobi_8.0 WattsStrogatz@@50
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 198.745
# gurobi_1.0 PowerlawCluster@@50
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 346.423
# gurobi_4.0 BarabasiAlbert@@400
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 2212.424
# gurobi_1.0 ErdosRenyi@@400
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 16491.6
# gurobi_4.0 ErdosRenyi@@50
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 530.111
# gurobi_0.1 BarabasiAlbert@@100
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 719.406
# gurobi_1.0 WattsStrogatz@@400
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 1175.974
# gurobi_8.0 ENZYMES
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES gurobi: 81.45
# gurobi_4.0 PowerlawCluster@@50
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 346.424
# gurobi_0.5 WattsStrogatz@@400
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 1173.505
# gurobi_1.0 REDDIT-MULTI-12K
# load_baseline_outputs: REDDIT-MULTI-12K length: 100
# load_baseline_outputs: REDDIT-MULTI-12K gurobi: 568.91
# gurobi_0.5 MUTAG
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG gurobi: 27.94736842105263
# gurobi_0.5 WattsStrogatz@@50
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz gurobi: 198.745
# gurobi_8.0 PowerlawCluster@@400
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 2173.876
# gurobi_4.0 REDDIT-MULTI-12K
# load_baseline_outputs: REDDIT-MULTI-12K length: 100
# load_baseline_outputs: REDDIT-MULTI-12K gurobi: 568.92
# gurobi_8.0 PowerlawCluster@@50
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster gurobi: 346.424
# gurobi_1.0 IMDB-BINARY
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY gurobi: 97.495
# gurobi_4.0 BarabasiAlbert@@50
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 352.121
# gurobi_0.1 ErdosRenyi@@400
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 16476.722
# gurobi_4.0 COLLAB
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB gurobi: 2624.607
# gurobi_4.0 IMDB-BINARY
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY gurobi: 97.495
# gurobi_0.5 BarabasiAlbert@@100
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 719.507
# gurobi_8.0 ErdosRenyi@@50
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi gurobi: 530.163
# gurobi_2.0 BarabasiAlbert@@100
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert gurobi: 719.803
# gurobi_0.5 PROTEINS
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS gurobi: 102.36160714285714

# %%
for baseline_folder in baseline_folders_greedy:
    for model_folder in os.listdir(os.path.join(root_folder, baseline_folder)):
        with open(os.path.join(os.path.join(root_folder, baseline_folder, model_folder), 'params.txt'), 'r') as f:
            model_args = json.load(f)
        if model_args['problem_type'] != 'max_cut':
            continue
        
        #print(model_args['gurobi'], model_args['gurobi_timeout'], model_args['dataset'], model_args['gen_n'])
        #print(load_baseline_outputs(Path(os.path.join(root_folder, baseline_folder)), model_folder, 'gurobi', indices))
        row = f'greedy'
        if isinstance(model_args['gen_n'], list):
            col = f"{model_args['dataset']}@@{model_args['gen_n'][0]}"
        else:
            col = f"{model_args['dataset']}"
        print(row,col)

        val = load_baseline_outputs(Path(os.path.join(root_folder, baseline_folder)), model_folder, 'greedy') # indices)
        
        vc_scores.at[ row , col] = list(val.values())[0]
        #vc_scores.at[ row , 'gen_n'] = model_args['gen_n']
        #vc_scores.at[ row , ''] = model_args['gen_n']
# Out:
# greedy ErdosRenyi@@100
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi greedy: 1097.259
# greedy IMDB-BINARY
# load_baseline_outputs: IMDB-BINARY length: 100
# load_baseline_outputs: IMDB-BINARY greedy: 51.85
# greedy REDDIT-MULTI-5K
# load_baseline_outputs: REDDIT-MULTI-5K length: 100
# load_baseline_outputs: REDDIT-MULTI-5K greedy: 495.02
# greedy MUTAG
# load_baseline_outputs: MUTAG length: 19
# load_baseline_outputs: MUTAG greedy: 16.94736842105263
# greedy WattsStrogatz@@50
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz greedy: 116.65
# greedy REDDIT-BINARY
# load_baseline_outputs: REDDIT-BINARY length: 100
# load_baseline_outputs: REDDIT-BINARY greedy: 439.79
# greedy PowerlawCluster@@100
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster greedy: 402.539
# greedy ErdosRenyi@@50
# load_baseline_outputs: ErdosRenyi length: 1000
# load_baseline_outputs: ErdosRenyi greedy: 298.546
# greedy BarabasiAlbert@@100
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert greedy: 407.981
# greedy PowerlawCluster@@400
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster greedy: 1230.981
# greedy ErdosRenyi@@400
# load_baseline_outputs: ErdosRenyi length: 244
# load_baseline_outputs: ErdosRenyi greedy: 8622.33606557377
# greedy PROTEINS
# load_baseline_outputs: PROTEINS length: 112
# load_baseline_outputs: PROTEINS greedy: 60.74107142857143
# greedy COLLAB
# load_baseline_outputs: COLLAB length: 500
# load_baseline_outputs: COLLAB greedy: 1345.7
# greedy ENZYMES
# load_baseline_outputs: ENZYMES length: 60
# load_baseline_outputs: ENZYMES greedy: 48.53333333333333
# greedy PowerlawCluster@@50
# load_baseline_outputs: PowerlawCluster length: 1000
# load_baseline_outputs: PowerlawCluster greedy: 196.234
# greedy BarabasiAlbert@@400
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert greedy: 1255.219
# greedy WattsStrogatz@@100
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz greedy: 229.433
# greedy BarabasiAlbert@@50
# load_baseline_outputs: BarabasiAlbert length: 1000
# load_baseline_outputs: BarabasiAlbert greedy: 200.097
# greedy WattsStrogatz@@400
# load_baseline_outputs: WattsStrogatz length: 1000
# load_baseline_outputs: WattsStrogatz greedy: 690.189
# greedy REDDIT-MULTI-12K
# load_baseline_outputs: REDDIT-MULTI-12K length: 100
# load_baseline_outputs: REDDIT-MULTI-12K greedy: 358.4

# %%
# putting max cut results in a table
maxcut_scores = pd.DataFrame(columns=dataset_names)

for (model, dataset), (train_losses, valid_scores) in maxcut_models.items():
    vc_scores.at[model, dataset] = np.max(valid_scores)
for (model, dataset), (train_losses, valid_scores) in maxcut_models.items():
    print(f"{model} {dataset} loss: {train_losses[-1]}")

for dataset, score in maxcut_sdp_lift.items():
    vc_scores.at['SDP lift', dataset] = score

for dataset, score in maxcut_sdp_proj.items():
    vc_scores.at['SDP proj', dataset] = score

for dataset in dataset_names:
    edges = 0
    count = 0
    if dataset not in datasets:
        continue
    for example in datasets[dataset]:
        edges += example.edge_index.shape[1]
        count += 1
    vc_scores.at['edge count', dataset] = float(edges) / count

#maxcut_scores.style.apply(lambda col: ['font-weight:bold' if x==col.max() else '' for x in col])

# %%
vc_scores
# Out:
#               PROTEINS       COLLAB  WattsStrogatz@@50  REDDIT-BINARY  \
# gurobi_2.0  102.361607  2624.595000            198.745        694.135
# gurobi_8.0  102.361607  2624.617000            198.745        694.135
# gurobi_0.1  102.281250  2624.321000            198.744        693.015
# gurobi_4.0  102.361607  2624.607000            198.745        694.135
# gurobi_0.5  102.361607  2624.511000            198.745        694.075
# gurobi_1.0  102.361607  2624.569000            198.745        694.105
# greedy       60.741071  1345.700000            116.650        439.790
# SDP lift    103.861852  2627.763179                NaN            NaN
# SDP proj    102.299107  2624.261000                NaN            NaN
# edge count  145.631626  4914.431600                NaN            NaN
#
#             ErdosRenyi@@400  PowerlawCluster@@100  PowerlawCluster@@400  \
# gurobi_2.0     16494.352000              712.4625              2169.860
# gurobi_8.0     16495.307000              712.8815              2173.876
# gurobi_0.1     16476.722000              711.6795              2169.456
# gurobi_4.0     16495.059000              712.6245              2173.765
# gurobi_0.5     16481.573000              711.8785              2169.456
# gurobi_1.0     16491.600000              712.2625              2169.458
# greedy          8622.336066              402.5390              1230.981
# SDP lift                NaN                   NaN                   NaN
# SDP proj                NaN                   NaN                   NaN
# edge count              NaN                   NaN                   NaN
#
#                ENZYMES  WattsStrogatz@@100  WattsStrogatz@@400  ...  \
# gurobi_2.0   81.450000             392.068            1177.892  ...
# gurobi_8.0   81.450000             392.068            1179.861  ...
# gurobi_0.1   81.450000             390.957            1173.450  ...
# gurobi_4.0   81.450000             392.068            1178.477  ...
# gurobi_0.5   81.450000             392.058            1173.505  ...
# gurobi_1.0   81.450000             392.067            1175.974  ...
# greedy       48.533333             229.433             690.189  ...
# SDP lift     82.517788                 NaN                 NaN  ...
# SDP proj     81.450000                 NaN                 NaN  ...
# edge count  124.273333                 NaN                 NaN  ...
#
#             ErdosRenyi@@50  ErdosRenyi@@100  BarabasiAlbert@@50  \
# gurobi_2.0         530.076        2002.8825             352.121
# gurobi_8.0         530.163        2002.9315             352.121
# gurobi_0.1         529.931        2002.8815             351.872
# gurobi_4.0         530.111        2002.8975             352.121
# gurobi_0.5         529.977        2002.8815             352.105
# gurobi_1.0         530.026        2002.8815             352.116
# greedy             298.546        1097.2590             200.097
# SDP lift               NaN              NaN                 NaN
# SDP proj               NaN              NaN                 NaN
# edge count             NaN              NaN                 NaN
#
#             PowerlawCluster@@50  BarabasiAlbert@@100  REDDIT-MULTI-5K  \
# gurobi_2.0              346.424              719.803          787.915
# gurobi_8.0              346.424              720.172          787.915
# gurobi_0.1              346.177              719.406          785.445
# gurobi_4.0              346.424              719.891          787.915
# gurobi_0.5              346.423              719.507          787.135
# gurobi_1.0              346.423              719.718          787.485
# greedy                  196.234              407.981          495.020
# SDP lift                    NaN                  NaN              NaN
# SDP proj                    NaN                  NaN              NaN
# edge count                  NaN                  NaN              NaN
#
#             IMDB-BINARY  REDDIT-MULTI-12K  BarabasiAlbert@@400      RANDOM
# gurobi_2.0    97.495000            568.91             2208.624         NaN
# gurobi_8.0    97.495000            568.94             2212.489         NaN
# gurobi_0.1    97.495000            567.71             2208.111         NaN
# gurobi_4.0    97.495000            568.92             2212.424         NaN
# gurobi_0.5    97.495000            568.76             2208.111         NaN
# gurobi_1.0    97.495000            568.91             2208.112         NaN
# greedy        51.850000            358.40             1255.219         NaN
# SDP lift      97.838509               NaN                  NaN  896.563787
# SDP proj      97.495000               NaN                  NaN  872.062500
# edge count   193.062000               NaN                  NaN         NaN
#
# [10 rows x 21 columns]

# %%
vc_scores.to_csv('/home/bcjexu/maxcut-80/bespoke-gnn4do/analysis_ipynb/mc_baseline_scores.csv')
vc_scores
# Out:
#               PROTEINS       COLLAB  WattsStrogatz@@50  REDDIT-BINARY  \
# gurobi_2.0  102.361607  2624.595000            198.745        694.135
# gurobi_8.0  102.361607  2624.617000            198.745        694.135
# gurobi_0.1  102.281250  2624.321000            198.744        693.015
# gurobi_4.0  102.361607  2624.607000            198.745        694.135
# gurobi_0.5  102.361607  2624.511000            198.745        694.075
# gurobi_1.0  102.361607  2624.569000            198.745        694.105
# greedy       60.741071  1345.700000            116.650        439.790
# SDP lift    103.861852  2627.763179                NaN            NaN
# SDP proj    102.299107  2624.261000                NaN            NaN
# edge count  145.631626  4914.431600                NaN            NaN
#
#             ErdosRenyi@@400  PowerlawCluster@@100  PowerlawCluster@@400  \
# gurobi_2.0     16494.352000              712.4625              2169.860
# gurobi_8.0     16495.307000              712.8815              2173.876
# gurobi_0.1     16476.722000              711.6795              2169.456
# gurobi_4.0     16495.059000              712.6245              2173.765
# gurobi_0.5     16481.573000              711.8785              2169.456
# gurobi_1.0     16491.600000              712.2625              2169.458
# greedy          8622.336066              402.5390              1230.981
# SDP lift                NaN                   NaN                   NaN
# SDP proj                NaN                   NaN                   NaN
# edge count              NaN                   NaN                   NaN
#
#                ENZYMES  WattsStrogatz@@100  WattsStrogatz@@400  ...  \
# gurobi_2.0   81.450000             392.068            1177.892  ...
# gurobi_8.0   81.450000             392.068            1179.861  ...
# gurobi_0.1   81.450000             390.957            1173.450  ...
# gurobi_4.0   81.450000             392.068            1178.477  ...
# gurobi_0.5   81.450000             392.058            1173.505  ...
# gurobi_1.0   81.450000             392.067            1175.974  ...
# greedy       48.533333             229.433             690.189  ...
# SDP lift     82.517788                 NaN                 NaN  ...
# SDP proj     81.450000                 NaN                 NaN  ...
# edge count  124.273333                 NaN                 NaN  ...
#
#             ErdosRenyi@@50  ErdosRenyi@@100  BarabasiAlbert@@50  \
# gurobi_2.0         530.076        2002.8825             352.121
# gurobi_8.0         530.163        2002.9315             352.121
# gurobi_0.1         529.931        2002.8815             351.872
# gurobi_4.0         530.111        2002.8975             352.121
# gurobi_0.5         529.977        2002.8815             352.105
# gurobi_1.0         530.026        2002.8815             352.116
# greedy             298.546        1097.2590             200.097
# SDP lift               NaN              NaN                 NaN
# SDP proj               NaN              NaN                 NaN
# edge count             NaN              NaN                 NaN
#
#             PowerlawCluster@@50  BarabasiAlbert@@100  REDDIT-MULTI-5K  \
# gurobi_2.0              346.424              719.803          787.915
# gurobi_8.0              346.424              720.172          787.915
# gurobi_0.1              346.177              719.406          785.445
# gurobi_4.0              346.424              719.891          787.915
# gurobi_0.5              346.423              719.507          787.135
# gurobi_1.0              346.423              719.718          787.485
# greedy                  196.234              407.981          495.020
# SDP lift                    NaN                  NaN              NaN
# SDP proj                    NaN                  NaN              NaN
# edge count                  NaN                  NaN              NaN
#
#             IMDB-BINARY  REDDIT-MULTI-12K  BarabasiAlbert@@400      RANDOM
# gurobi_2.0    97.495000            568.91             2208.624         NaN
# gurobi_8.0    97.495000            568.94             2212.489         NaN
# gurobi_0.1    97.495000            567.71             2208.111         NaN
# gurobi_4.0    97.495000            568.92             2212.424         NaN
# gurobi_0.5    97.495000            568.76             2208.111         NaN
# gurobi_1.0    97.495000            568.91             2208.112         NaN
# greedy        51.850000            358.40             1255.219         NaN
# SDP lift      97.838509               NaN                  NaN  896.563787
# SDP proj      97.495000               NaN                  NaN  872.062500
# edge count   193.062000               NaN                  NaN         NaN
#
# [10 rows x 21 columns]
