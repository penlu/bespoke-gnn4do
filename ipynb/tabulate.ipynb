# %%
# %load_ext autoreload
# %autoreload 2

import os
import json
import pandas as pd
import numpy as np
import sys
from pathlib import Path

root_folder = Path('/home/penlu/code/bespoke-gnn4do')
sys.path.insert(0, str(root_folder))

# %%
# loading max cut results from files

from utils.tabulate import load_datasets, load_train_outputs, load_baseline_outputs

print("loading model losses")
maxcut_models = load_train_outputs(root_folder / 'training_runs', '230823_test')
print("loading sdp lift losses")
maxcut_sdp_lift = load_baseline_outputs(root_folder / 'baseline_runs', '230824_sdp', 'sdp')
print("loading sdp proj losses")
maxcut_sdp_proj = load_baseline_outputs(root_folder / 'baseline_runs', '230824_sdp', 'sdp|random_hyperplane')
print("loading gurobi 1s")
maxcut_grb_1s = load_baseline_outputs(root_folder / 'baseline_runs', '230823_gurobi_1s', 'gurobi')
print("loading gurobi 5s")
maxcut_grb_5s = load_baseline_outputs(root_folder / 'baseline_runs', '230823_gurobi_5s', 'gurobi')
# Out:
# loading model losses
# load_train_outputs: got GatedGCNN, PROTEINS
# load_train_outputs: got GAT, MUTAG
# load_train_outputs: got GCNN, RANDOM
# load_train_outputs: got GCNN, ENZYMES
# load_train_outputs: got GCNN, IMDB-BINARY
# load_train_outputs: got GatedGCNN, RANDOM
# load_train_outputs: got GAT, IMDB-BINARY
# load_train_outputs: got LiftMP, COLLAB
# load_train_outputs: got GCNN, COLLAB
# load_train_outputs: got GIN, IMDB-BINARY
# load_train_outputs: got GIN, PROTEINS
# load_train_outputs: got GatedGCNN, IMDB-BINARY
# load_train_outputs: got GAT, PROTEINS
# load_train_outputs: got LiftMP, RANDOM
# load_train_outputs: got LiftMP, ENZYMES
# load_train_outputs: got GatedGCNN, MUTAG
# load_train_outputs: got GIN, COLLAB
# load_train_outputs: got GAT, ENZYMES
# load_train_outputs: got LiftMP, IMDB-BINARY
# load_train_outputs: got GIN, MUTAG
# load_train_outputs: got GCNN, PROTEINS
# load_train_outputs: got GIN, ENZYMES
# load_train_outputs: got LiftMP, MUTAG
# load_train_outputs: got LiftMP, PROTEINS
# load_train_outputs: got GAT, COLLAB
# load_train_outputs: got GIN, RANDOM
# load_train_outputs: got GatedGCNN, COLLAB
# load_train_outputs: got GCNN, MUTAG
# load_train_outputs: got GAT, RANDOM
# load_train_outputs: got GatedGCNN, ENZYMES
# loading sdp lift losses
# load_baseline_outputs: COLLAB length: 5000
# load_baseline_outputs: COLLAB sdp: 2527.2064663589476
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM sdp: 896.5637869873046
# load_baseline_outputs: ENZYMES length: 600
# load_baseline_outputs: ENZYMES sdp: 81.79698029994965
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY sdp: 103.55589570999146
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS sdp: 96.45383225961088
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG sdp: 29.502876636829782
# loading sdp proj losses
# load_baseline_outputs: COLLAB length: 5000
# load_baseline_outputs: COLLAB sdp|random_hyperplane: 2523.9533
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM sdp|random_hyperplane: 872.0625
# load_baseline_outputs: ENZYMES length: 600
# load_baseline_outputs: ENZYMES sdp|random_hyperplane: 80.69666666666667
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY sdp|random_hyperplane: 103.1935
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS sdp|random_hyperplane: 94.99101527403414
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG sdp|random_hyperplane: 29.32712765957447
# loading gurobi 1s
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY gurobi: 103.1955
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG gurobi: 29.32712765957447
# load_baseline_outputs: COLLAB length: 5000
# load_baseline_outputs: COLLAB gurobi: 2524.2921
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS gurobi: 95.0763701707098
# load_baseline_outputs: ENZYMES length: 600
# load_baseline_outputs: ENZYMES gurobi: 80.71
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM gurobi: 874.1265
# loading gurobi 5s
# load_baseline_outputs: ENZYMES length: 600
# load_baseline_outputs: ENZYMES gurobi: 80.71
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS gurobi: 95.0763701707098
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM gurobi: 874.2815
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG gurobi: 29.32712765957447
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY gurobi: 103.1965
# load_baseline_outputs: COLLAB length: 5000
# load_baseline_outputs: COLLAB gurobi: 2524.3399

# %%
# putting max cut results in a table

dataset_names = ['RANDOM', 'ENZYMES', 'PROTEINS', 'IMDB-BINARY', 'MUTAG', 'COLLAB']
maxcut_scores = pd.DataFrame(columns=dataset_names)

for (model, dataset), (train_losses, valid_scores) in maxcut_models.items():
    maxcut_scores.at[model, dataset] = valid_scores[-1]
for dataset, score in maxcut_sdp_lift.items():
    maxcut_scores.at['SDP lift', dataset] = score
for dataset, score in maxcut_sdp_proj.items():
    maxcut_scores.at['SDP proj', dataset] = score
for dataset, score in maxcut_grb_1s.items():
    maxcut_scores.at['gurobi 1s', dataset] = score
for dataset, score in maxcut_grb_5s.items():
    maxcut_scores.at['gurobi 5s', dataset] = score

# %%
maxcut_scores
# Out:
#                RANDOM    ENZYMES   PROTEINS IMDB-BINARY      MUTAG  \
# GatedGCNN    867.6525  78.879167   92.90583    116.0275  28.855263
# GAT          870.2025  76.241667  93.887892      73.245  29.605263
# GCNN         824.1825  45.641667  72.484305       63.69       20.0
# LiftMP       871.0525  79.179167  93.049327    116.3825  28.855263
# GIN          800.5025       65.5  88.040359      68.495  21.368421
# SDP lift   896.563787   81.79698  96.453832  103.555896  29.502877
# SDP proj     872.0625  80.696667  94.991015    103.1935  29.327128
# gurobi 1s    874.1265      80.71   95.07637    103.1955  29.327128
# gurobi 5s    874.2815      80.71   95.07637    103.1965  29.327128
#
#                 COLLAB
# GatedGCNN     1950.527
# GAT          2504.0655
# GCNN          2002.211
# LiftMP       2704.1985
# GIN           2240.236
# SDP lift   2527.206466
# SDP proj     2523.9533
# gurobi 1s    2524.2921
# gurobi 5s    2524.3399

# %%
# loading vertex cover results from files

from utils.tabulate import load_datasets, load_train_outputs, load_baseline_outputs

print("loading model losses")
vc_models = load_train_outputs(root_folder / 'training_runs', '230901_VC')
print("loading sdp lift losses")
vc_sdp_lift = load_baseline_outputs(root_folder / 'baseline_runs', '230902_VC_sdp', 'sdp')
print("loading sdp proj losses")
vc_sdp_proj = load_baseline_outputs(root_folder / 'baseline_runs', '230902_VC_sdp', 'sdp|random_hyperplane')
print("loading gurobi 1s")
vc_grb_1s = load_baseline_outputs(root_folder / 'baseline_runs', '230902_gurobi_1s', 'gurobi')
print("loading gurobi 5s")
vc_grb_5s = load_baseline_outputs(root_folder / 'baseline_runs', '230902_gurobi_5s', 'gurobi')
# Out:
# loading model losses
# load_train_outputs: got GAT, PROTEINS
# load_train_outputs: got GCNN, PROTEINS
# load_train_outputs: got GCNN, RANDOM
# load_train_outputs: got NegationGAT, COLLAB
# load_train_outputs: got GIN, COLLAB
# load_train_outputs: got GatedGCNN, PROTEINS
# load_train_outputs: got GatedGCNN, COLLAB
# load_train_outputs: got GCNN, COLLAB
# load_train_outputs: got GIN, RANDOM
# load_train_outputs: got GCNN, MUTAG
# load_train_outputs: got GIN, PROTEINS
# load_train_outputs: got NegationGAT, MUTAG
# load_train_outputs: got NegationGAT, RANDOM
# load_train_outputs: got GatedGCNN, RANDOM
# load_train_outputs: got LiftMP, ENZYMES
# load_train_outputs: got GIN, MUTAG
# load_train_outputs: got GAT, RANDOM
# load_train_outputs: got GIN, ENZYMES
# load_train_outputs: got NegationGAT, PROTEINS
# load_train_outputs: got GatedGCNN, MUTAG
# load_train_outputs: got LiftMP, MUTAG
# load_train_outputs: got NegationGAT, IMDB-BINARY
# load_train_outputs: got GCNN, ENZYMES
# load_train_outputs: got LiftMP, PROTEINS
# load_train_outputs: got GAT, IMDB-BINARY
# load_train_outputs: got LiftMP, RANDOM
# load_train_outputs: got GIN, IMDB-BINARY
# load_train_outputs: got GAT, COLLAB
# load_train_outputs: got GAT, MUTAG
# load_train_outputs: got GAT, ENZYMES
# load_train_outputs: got GatedGCNN, IMDB-BINARY
# load_train_outputs: got NegationGAT, ENZYMES
# load_train_outputs: got LiftMP, IMDB-BINARY
# load_train_outputs: got GatedGCNN, ENZYMES
# load_train_outputs: got GCNN, IMDB-BINARY
# load_train_outputs: got LiftMP, COLLAB
# loading sdp lift losses
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG sdp: -8.149278062455197
# load_baseline_outputs: COLLAB length: 1047
# load_baseline_outputs: COLLAB sdp: -54.37127593731812
# load_baseline_outputs: ENZYMES length: 600
# load_baseline_outputs: ENZYMES sdp: -19.83108720719814
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS sdp: -23.595317618866172
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM sdp: -73.35152729797363
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY sdp: -16.60996855020523
# loading sdp proj losses
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG sdp|random_hyperplane: -8.170212765957446
# load_baseline_outputs: COLLAB length: 1047
# load_baseline_outputs: COLLAB sdp|random_hyperplane: -54.54536771728749
# load_baseline_outputs: ENZYMES length: 600
# load_baseline_outputs: ENZYMES sdp|random_hyperplane: -19.863333333333333
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS sdp|random_hyperplane: -23.690925426774484
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM sdp|random_hyperplane: -81.3
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY sdp|random_hyperplane: -16.63
# loading gurobi 1s
# load_baseline_outputs: COLLAB length: 5000
# load_baseline_outputs: COLLAB gurobi: -65.3958
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS gurobi: -23.628032345013477
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM gurobi: -75.926
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG gurobi: -8.170212765957446
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY gurobi: -16.613
# loading gurobi 5s
# load_baseline_outputs: COLLAB length: 5000
# load_baseline_outputs: COLLAB gurobi: -65.3958
# load_baseline_outputs: RANDOM length: 1000
# load_baseline_outputs: RANDOM gurobi: -75.926
# load_baseline_outputs: PROTEINS length: 1113
# load_baseline_outputs: PROTEINS gurobi: -23.628032345013477
# load_baseline_outputs: MUTAG length: 188
# load_baseline_outputs: MUTAG gurobi: -8.170212765957446
# load_baseline_outputs: IMDB-BINARY length: 1000
# load_baseline_outputs: IMDB-BINARY gurobi: -16.613

# %%
# putting vertex cover results in a table

dataset_names = ['RANDOM', 'ENZYMES', 'PROTEINS', 'IMDB-BINARY', 'MUTAG', 'COLLAB']
vc_scores = pd.DataFrame(columns=dataset_names)

for (model, dataset), (train_losses, valid_scores) in vc_models.items():
    vc_scores.at[model, dataset] = valid_scores[-1]
for dataset, score in vc_sdp_lift.items():
    vc_scores.at['SDP lift', dataset] = score
for dataset, score in vc_sdp_proj.items():
    vc_scores.at['SDP proj', dataset] = score
for dataset, score in vc_grb_1s.items():
    vc_scores.at['gurobi 1s', dataset] = score
for dataset, score in vc_grb_5s.items():
    vc_scores.at['gurobi 5s', dataset] = score

# %%
vc_scores
# Out:
#                 RANDOM    ENZYMES   PROTEINS IMDB-BINARY      MUTAG     COLLAB
# GAT            -81.305 -22.683333 -30.587444      -18.28  -8.710526    -69.898
# GCNN           -94.525      -32.8 -52.950673     -18.625 -17.184211    -72.944
# NegationGAT      -97.6 -28.241667  -34.64574     -19.055 -13.921053    -73.959
# GIN            -151.84 -37.941667 -60.941704       -18.4 -10.131579    -72.371
# GatedGCNN      -85.985 -20.291667 -26.336323      -18.48  -8.236842    -74.237
# LiftMP         -95.225 -19.458333 -25.690583     -18.455  -8.236842    -69.621
# SDP lift    -73.351527 -19.831087 -23.595318  -16.609969  -8.149278 -54.371276
# SDP proj         -81.3 -19.863333 -23.690925      -16.63  -8.170213 -54.545368
# gurobi 1s      -75.926        NaN -23.628032     -16.613  -8.170213   -65.3958
# gurobi 5s      -75.926        NaN -23.628032     -16.613  -8.170213   -65.3958
