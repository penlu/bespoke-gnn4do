# %%
import argparse
import logging
import os
import pdb
import random
import numpy as np
from cnf import CNF
import pysat
from os import listdir
from pysat.formula import CNF
from pysat.solvers import Lingeling,Minisat22, Glucose4
import pickle
from pysat.examples.rc2 import RC2

# %% [markdown]
# ## WALKSAT CODE

# %%
def parse(filename):
    clauses = []
    count = 0
    for line in open(filename):

        if line[0] == 'c':
            continue
        if line[0] == 'p':
            n_vars = int(line.split()[2])
            lit_clause = [[] for _ in range(n_vars * 2 + 1)]
            continue

        clause = []
        for literal in line[:-2].split():
            literal = int(literal)
            clause.append(literal)
            lit_clause[literal].append(count)
        clauses.append(clause)
        count += 1
    return clauses, n_vars, lit_clause


def get_random_interpretation(n_vars):
    return [i if random.random() < 0.5 else -i for i in range(n_vars + 1)]


def get_true_sat_lit(clauses, interpretation):
    true_sat_lit = [0 for _ in clauses]
    for index, clause in enumerate(clauses):
        for lit in clause:
            if interpretation[abs(lit)] == lit:
                true_sat_lit[index] += 1
    return true_sat_lit


def update_tsl(literal_to_flip, true_sat_lit, lit_clause):
    for clause_index in lit_clause[literal_to_flip]:
        true_sat_lit[clause_index] += 1
    for clause_index in lit_clause[-literal_to_flip]:
        true_sat_lit[clause_index] -= 1


def compute_broken(clause, true_sat_lit, lit_clause, omega=0.4):
    break_min = 999999999
    best_literals = []
    for literal in clause:

        break_score = 0

        for clause_index in lit_clause[-literal]:
            if true_sat_lit[clause_index] == 1:
                break_score += 1

        if break_score < break_min:
            break_min = break_score
            best_literals = [literal]
        elif break_score == break_min:
            best_literals.append(literal)

    if break_min != 0 and random.random() < omega:
        best_literals = clause

    return random.choice(best_literals)


def run_sat(clauses, n_vars, lit_clause, max_flips_proportion=4, max_tries=500):
    max_flips = n_vars * max_flips_proportion
    tries = 0
    num_unsat = len(clauses)
    while (tries <= max_tries):
        interpretation = get_random_interpretation(n_vars)
        true_sat_lit = get_true_sat_lit(clauses, interpretation)
        for _ in range(max_flips):

            unsatisfied_clauses_index = [index for index, true_lit in enumerate(true_sat_lit) if
                                         not true_lit]

            if not unsatisfied_clauses_index:
                num_unsat = 0 
                return interpretation, num_unsat

            clause_index = random.choice(unsatisfied_clauses_index)
            unsatisfied_clause = clauses[clause_index]

            lit_to_flip = compute_broken(unsatisfied_clause, true_sat_lit, lit_clause)

            update_tsl(lit_to_flip, true_sat_lit, lit_clause)

            interpretation[abs(lit_to_flip)] *= -1
            if len(unsatisfied_clauses_index) <= num_unsat:
                num_unsat = len(unsatisfied_clauses_index)
        tries+=1 
    return interpretation, num_unsat

# %% [markdown]
# ## Check satisfiability of instances in directory with pysat/glucose

# %%
file_scores = {}
dirname = 'dimacs_400_random/' ## ENTER DIRECTORY NAME WITH DIMACS FILES HERE
num_files = len(listdir(dirname))
count_unsat = 0
unsat_list = []
unsat_example = None 
for fl in listdir(dirname):
    my_formula = CNF(from_file=dirname+fl)
   # print(fl)
    with Glucose4(bootstrap_with=my_formula.clauses, with_proof=True) as l:
        is_sat = (l.solve())
        if  not is_sat:
            unsat_list += [fl.split('_')[1]]
            count_unsat+=1
            unsat_example = my_formula
        file_scores[fl] = [is_sat*1.]

# %% [markdown]
# ## Run walksat on instances in directory

# %%
dirname = 'dimacs_400_random/'
num_files = len(listdir(dirname))
count_unsat = 0
#unsat_list = []
num_unsatclauses_perinstance = []
unsat_example = None 
instance_count = 0
for fl in listdir(dirname):
    clauses, n_vars, lit_clause = parse(dirname+fl)
    solution, num_unsat = run_sat(clauses, n_vars, lit_clause, max_tries=100)
    num_unsatclauses_perinstance += [num_unsat]
    instance_count += 1 
    file_scores[fl] +=[num_unsat]
    print("Current instance: ", instance_count, "Num unsat clauses instance: ", num_unsat)
# Out:
# Current instance:  1 Num unsat clauses instance:  0
# Current instance:  2 Num unsat clauses instance:  0
# Current instance:  3 Num unsat clauses instance:  0
# Current instance:  4 Num unsat clauses instance:  1
# Current instance:  5 Num unsat clauses instance:  0
# Current instance:  6 Num unsat clauses instance:  0
# Current instance:  7 Num unsat clauses instance:  0
# Current instance:  8 Num unsat clauses instance:  0
# Current instance:  9 Num unsat clauses instance:  0
# Current instance:  10 Num unsat clauses instance:  1
# Current instance:  11 Num unsat clauses instance:  0
# Current instance:  12 Num unsat clauses instance:  1
# Current instance:  13 Num unsat clauses instance:  1
# Current instance:  14 Num unsat clauses instance:  1
# Current instance:  15 Num unsat clauses instance:  0
# Current instance:  16 Num unsat clauses instance:  1
# Current instance:  17 Num unsat clauses instance:  0
# Current instance:  18 Num unsat clauses instance:  0
# Current instance:  19 Num unsat clauses instance:  1
# Current instance:  20 Num unsat clauses instance:  0
# Current instance:  21 Num unsat clauses instance:  0
# Current instance:  22 Num unsat clauses instance:  0
# Current instance:  23 Num unsat clauses instance:  0
# Current instance:  24 Num unsat clauses instance:  0
# Current instance:  25 Num unsat clauses instance:  0
# Current instance:  26 Num unsat clauses instance:  0
# Current instance:  27 Num unsat clauses instance:  0
# Current instance:  28 Num unsat clauses instance:  0
# Current instance:  29 Num unsat clauses instance:  0
# Current instance:  30 Num unsat clauses instance:  0
# Current instance:  31 Num unsat clauses instance:  0
# Current instance:  32 Num unsat clauses instance:  0
# Current instance:  33 Num unsat clauses instance:  0
# Current instance:  34 Num unsat clauses instance:  0
# Current instance:  35 Num unsat clauses instance:  0
# Current instance:  36 Num unsat clauses instance:  0
# Current instance:  37 Num unsat clauses instance:  0
# Current instance:  38 Num unsat clauses instance:  0
# Current instance:  39 Num unsat clauses instance:  0
# Current instance:  40 Num unsat clauses instance:  0
# Current instance:  41 Num unsat clauses instance:  0
# Current instance:  42 Num unsat clauses instance:  1
# Current instance:  43 Num unsat clauses instance:  0
# Current instance:  44 Num unsat clauses instance:  0
# Current instance:  45 Num unsat clauses instance:  1
# Current instance:  46 Num unsat clauses instance:  0
# Current instance:  47 Num unsat clauses instance:  0
# Current instance:  48 Num unsat clauses instance:  0
# Current instance:  49 Num unsat clauses instance:  0
# Current instance:  50 Num unsat clauses instance:  0
# Current instance:  51 Num unsat clauses instance:  0
# Current instance:  52 Num unsat clauses instance:  1
# Current instance:  53 Num unsat clauses instance:  0
# Current instance:  54 Num unsat clauses instance:  0
# Current instance:  55 Num unsat clauses instance:  0
# Current instance:  56 Num unsat clauses instance:  0
# Current instance:  57 Num unsat clauses instance:  0
# Current instance:  58 Num unsat clauses instance:  0
# Current instance:  59 Num unsat clauses instance:  0
# Current instance:  60 Num unsat clauses instance:  0
# Current instance:  61 Num unsat clauses instance:  0
# Current instance:  62 Num unsat clauses instance:  0
# Current instance:  63 Num unsat clauses instance:  0
# Current instance:  64 Num unsat clauses instance:  0
# Current instance:  65 Num unsat clauses instance:  0
# Current instance:  66 Num unsat clauses instance:  0
# Current instance:  67 Num unsat clauses instance:  0
# Current instance:  68 Num unsat clauses instance:  0
# Current instance:  69 Num unsat clauses instance:  0
# Current instance:  70 Num unsat clauses instance:  0
# Current instance:  71 Num unsat clauses instance:  0
# Current instance:  72 Num unsat clauses instance:  0
# Current instance:  73 Num unsat clauses instance:  0
# Current instance:  74 Num unsat clauses instance:  0
# Current instance:  75 Num unsat clauses instance:  0
# Current instance:  76 Num unsat clauses instance:  0
# Current instance:  77 Num unsat clauses instance:  0
# Current instance:  78 Num unsat clauses instance:  0
# Current instance:  79 Num unsat clauses instance:  0
# Current instance:  80 Num unsat clauses instance:  0
# Current instance:  81 Num unsat clauses instance:  0
# Current instance:  82 Num unsat clauses instance:  1
# Current instance:  83 Num unsat clauses instance:  0
# Current instance:  84 Num unsat clauses instance:  0
# Current instance:  85 Num unsat clauses instance:  0
# Current instance:  86 Num unsat clauses instance:  0
# Current instance:  87 Num unsat clauses instance:  0
# Current instance:  88 Num unsat clauses instance:  0
# Current instance:  89 Num unsat clauses instance:  1
# Current instance:  90 Num unsat clauses instance:  0
# Current instance:  91 Num unsat clauses instance:  1
# Current instance:  92 Num unsat clauses instance:  0
# Current instance:  93 Num unsat clauses instance:  0
# Current instance:  94 Num unsat clauses instance:  0
# Current instance:  95 Num unsat clauses instance:  1
# Current instance:  96 Num unsat clauses instance:  0
# Current instance:  97 Num unsat clauses instance:  0
# Current instance:  98 Num unsat clauses instance:  0
# Current instance:  99 Num unsat clauses instance:  0
# Current instance:  100 Num unsat clauses instance:  0
# Current instance:  101 Num unsat clauses instance:  0
# Current instance:  102 Num unsat clauses instance:  0
# Current instance:  103 Num unsat clauses instance:  0
# Current instance:  104 Num unsat clauses instance:  0
# Current instance:  105 Num unsat clauses instance:  0
# Current instance:  106 Num unsat clauses instance:  0
# Current instance:  107 Num unsat clauses instance:  0
# Current instance:  108 Num unsat clauses instance:  0
# Current instance:  109 Num unsat clauses instance:  1
# Current instance:  110 Num unsat clauses instance:  0
# Current instance:  111 Num unsat clauses instance:  0
# Current instance:  112 Num unsat clauses instance:  0
# Current instance:  113 Num unsat clauses instance:  0
# Current instance:  114 Num unsat clauses instance:  0
# Current instance:  115 Num unsat clauses instance:  1
# Current instance:  116 Num unsat clauses instance:  0
# Current instance:  117 Num unsat clauses instance:  0
# Current instance:  118 Num unsat clauses instance:  0
# Current instance:  119 Num unsat clauses instance:  0
# Current instance:  120 Num unsat clauses instance:  0
# Current instance:  121 Num unsat clauses instance:  0
# Current instance:  122 Num unsat clauses instance:  0
# Current instance:  123 Num unsat clauses instance:  1
# Current instance:  124 Num unsat clauses instance:  0
# Current instance:  125 Num unsat clauses instance:  0
# Current instance:  126 Num unsat clauses instance:  0
# Current instance:  127 Num unsat clauses instance:  0
# Current instance:  128 Num unsat clauses instance:  0
# Current instance:  129 Num unsat clauses instance:  0
# Current instance:  130 Num unsat clauses instance:  0
# Current instance:  131 Num unsat clauses instance:  1
# Current instance:  132 Num unsat clauses instance:  1
# Current instance:  133 Num unsat clauses instance:  1
# Current instance:  134 Num unsat clauses instance:  0
# Current instance:  135 Num unsat clauses instance:  0
# Current instance:  136 Num unsat clauses instance:  0
# Current instance:  137 Num unsat clauses instance:  0
# Current instance:  138 Num unsat clauses instance:  0
# Current instance:  139 Num unsat clauses instance:  0
# Current instance:  140 Num unsat clauses instance:  1
# Current instance:  141 Num unsat clauses instance:  0
# Current instance:  142 Num unsat clauses instance:  1
# Current instance:  143 Num unsat clauses instance:  1
# Current instance:  144 Num unsat clauses instance:  1
# Current instance:  145 Num unsat clauses instance:  0
# Current instance:  146 Num unsat clauses instance:  0
# Current instance:  147 Num unsat clauses instance:  0
# Current instance:  148 Num unsat clauses instance:  0
# Current instance:  149 Num unsat clauses instance:  0
# Current instance:  150 Num unsat clauses instance:  0
# Current instance:  151 Num unsat clauses instance:  0
# Current instance:  152 Num unsat clauses instance:  0
# Current instance:  153 Num unsat clauses instance:  0
# Current instance:  154 Num unsat clauses instance:  2
# Current instance:  155 Num unsat clauses instance:  0
# Current instance:  156 Num unsat clauses instance:  0
# Current instance:  157 Num unsat clauses instance:  0
# Current instance:  158 Num unsat clauses instance:  0
# Current instance:  159 Num unsat clauses instance:  0
# Current instance:  160 Num unsat clauses instance:  0
# Current instance:  161 Num unsat clauses instance:  0
# Current instance:  162 Num unsat clauses instance:  0
# Current instance:  163 Num unsat clauses instance:  0
# Current instance:  164 Num unsat clauses instance:  0
# Current instance:  165 Num unsat clauses instance:  1
# Current instance:  166 Num unsat clauses instance:  0
# Current instance:  167 Num unsat clauses instance:  0
# Current instance:  168 Num unsat clauses instance:  0
# Current instance:  169 Num unsat clauses instance:  0
# Current instance:  170 Num unsat clauses instance:  1
# Current instance:  171 Num unsat clauses instance:  0
# Current instance:  172 Num unsat clauses instance:  0
# Current instance:  173 Num unsat clauses instance:  0
# Current instance:  174 Num unsat clauses instance:  0
# Current instance:  175 Num unsat clauses instance:  0
# Current instance:  176 Num unsat clauses instance:  0
# Current instance:  177 Num unsat clauses instance:  0
# Current instance:  178 Num unsat clauses instance:  1
# Current instance:  179 Num unsat clauses instance:  0
# Current instance:  180 Num unsat clauses instance:  0
# Current instance:  181 Num unsat clauses instance:  1
# Current instance:  182 Num unsat clauses instance:  0
# Current instance:  183 Num unsat clauses instance:  0
# Current instance:  184 Num unsat clauses instance:  0
# Current instance:  185 Num unsat clauses instance:  1
# Current instance:  186 Num unsat clauses instance:  0
# Current instance:  187 Num unsat clauses instance:  0
# Current instance:  188 Num unsat clauses instance:  0
# Current instance:  189 Num unsat clauses instance:  0
# Current instance:  190 Num unsat clauses instance:  0
# Current instance:  191 Num unsat clauses instance:  0
# Current instance:  192 Num unsat clauses instance:  0
# Current instance:  193 Num unsat clauses instance:  0
# Current instance:  194 Num unsat clauses instance:  0
# Current instance:  195 Num unsat clauses instance:  1
# Current instance:  196 Num unsat clauses instance:  0
# Current instance:  197 Num unsat clauses instance:  0
# Current instance:  198 Num unsat clauses instance:  0
# Current instance:  199 Num unsat clauses instance:  0
# Current instance:  200 Num unsat clauses instance:  0
# Current instance:  201 Num unsat clauses instance:  0
# Current instance:  202 Num unsat clauses instance:  0
# Current instance:  203 Num unsat clauses instance:  0
# Current instance:  204 Num unsat clauses instance:  0
# Current instance:  205 Num unsat clauses instance:  0
# Current instance:  206 Num unsat clauses instance:  0
# Current instance:  207 Num unsat clauses instance:  0
# Current instance:  208 Num unsat clauses instance:  0
# Current instance:  209 Num unsat clauses instance:  0
# Current instance:  210 Num unsat clauses instance:  0
# Current instance:  211 Num unsat clauses instance:  0
# Current instance:  212 Num unsat clauses instance:  1
# Current instance:  213 Num unsat clauses instance:  0
# Current instance:  214 Num unsat clauses instance:  0
# Current instance:  215 Num unsat clauses instance:  1
# Current instance:  216 Num unsat clauses instance:  0
# Current instance:  217 Num unsat clauses instance:  0
# Current instance:  218 Num unsat clauses instance:  0
# Current instance:  219 Num unsat clauses instance:  0
# Current instance:  220 Num unsat clauses instance:  0
# Current instance:  221 Num unsat clauses instance:  1
# Current instance:  222 Num unsat clauses instance:  0
# Current instance:  223 Num unsat clauses instance:  0
# Current instance:  224 Num unsat clauses instance:  0
# Current instance:  225 Num unsat clauses instance:  0
# Current instance:  226 Num unsat clauses instance:  1
# Current instance:  227 Num unsat clauses instance:  0
# Current instance:  228 Num unsat clauses instance:  0
# Current instance:  229 Num unsat clauses instance:  0
# Current instance:  230 Num unsat clauses instance:  0
# Current instance:  231 Num unsat clauses instance:  0
# Current instance:  232 Num unsat clauses instance:  0
# Current instance:  233 Num unsat clauses instance:  0
# Current instance:  234 Num unsat clauses instance:  0
# Current instance:  235 Num unsat clauses instance:  1
# Current instance:  236 Num unsat clauses instance:  0
# Current instance:  237 Num unsat clauses instance:  0
# Current instance:  238 Num unsat clauses instance:  0
# Current instance:  239 Num unsat clauses instance:  1
# Current instance:  240 Num unsat clauses instance:  0
# Current instance:  241 Num unsat clauses instance:  0
# Current instance:  242 Num unsat clauses instance:  0
# Current instance:  243 Num unsat clauses instance:  1
# Current instance:  244 Num unsat clauses instance:  0
# Current instance:  245 Num unsat clauses instance:  0
# Current instance:  246 Num unsat clauses instance:  0
# Current instance:  247 Num unsat clauses instance:  0
# Current instance:  248 Num unsat clauses instance:  0
# Current instance:  249 Num unsat clauses instance:  0
# Current instance:  250 Num unsat clauses instance:  1
# Current instance:  251 Num unsat clauses instance:  0
# Current instance:  252 Num unsat clauses instance:  0
# Current instance:  253 Num unsat clauses instance:  0
# Current instance:  254 Num unsat clauses instance:  1
# Current instance:  255 Num unsat clauses instance:  0
# Current instance:  256 Num unsat clauses instance:  1
# Current instance:  257 Num unsat clauses instance:  0
# Current instance:  258 Num unsat clauses instance:  0
# Current instance:  259 Num unsat clauses instance:  1
# Current instance:  260 Num unsat clauses instance:  0
# Current instance:  261 Num unsat clauses instance:  0
# Current instance:  262 Num unsat clauses instance:  0
# Current instance:  263 Num unsat clauses instance:  0
# Current instance:  264 Num unsat clauses instance:  0
# Current instance:  265 Num unsat clauses instance:  0
# Current instance:  266 Num unsat clauses instance:  0
# Current instance:  267 Num unsat clauses instance:  0
# Current instance:  268 Num unsat clauses instance:  0
# Current instance:  269 Num unsat clauses instance:  0
# Current instance:  270 Num unsat clauses instance:  0
# Current instance:  271 Num unsat clauses instance:  0
# Current instance:  272 Num unsat clauses instance:  0
# Current instance:  273 Num unsat clauses instance:  0
# Current instance:  274 Num unsat clauses instance:  1
# Current instance:  275 Num unsat clauses instance:  0
# Current instance:  276 Num unsat clauses instance:  0
# Current instance:  277 Num unsat clauses instance:  1
# Current instance:  278 Num unsat clauses instance:  0
# Current instance:  279 Num unsat clauses instance:  0
# Current instance:  280 Num unsat clauses instance:  0
# Current instance:  281 Num unsat clauses instance:  0
# Current instance:  282 Num unsat clauses instance:  0
# Current instance:  283 Num unsat clauses instance:  0
# Current instance:  284 Num unsat clauses instance:  0
# Current instance:  285 Num unsat clauses instance:  0
# Current instance:  286 Num unsat clauses instance:  1
# Current instance:  287 Num unsat clauses instance:  0
# Current instance:  288 Num unsat clauses instance:  1
# Current instance:  289 Num unsat clauses instance:  0
# Current instance:  290 Num unsat clauses instance:  0
# Current instance:  291 Num unsat clauses instance:  0
# Current instance:  292 Num unsat clauses instance:  0
# Current instance:  293 Num unsat clauses instance:  0
# Current instance:  294 Num unsat clauses instance:  0
# Current instance:  295 Num unsat clauses instance:  0
# Current instance:  296 Num unsat clauses instance:  0
# Current instance:  297 Num unsat clauses instance:  0
# Current instance:  298 Num unsat clauses instance:  0
# Current instance:  299 Num unsat clauses instance:  0
# Current instance:  300 Num unsat clauses instance:  0
# Current instance:  301 Num unsat clauses instance:  0
# Current instance:  302 Num unsat clauses instance:  0
# Current instance:  303 Num unsat clauses instance:  0
# Current instance:  304 Num unsat clauses instance:  0
# Current instance:  305 Num unsat clauses instance:  0
# Current instance:  306 Num unsat clauses instance:  0
# Current instance:  307 Num unsat clauses instance:  0
# Current instance:  308 Num unsat clauses instance:  1
# Current instance:  309 Num unsat clauses instance:  0
# Current instance:  310 Num unsat clauses instance:  0
# Current instance:  311 Num unsat clauses instance:  0
# Current instance:  312 Num unsat clauses instance:  0
# Current instance:  313 Num unsat clauses instance:  0
# Current instance:  314 Num unsat clauses instance:  0
# Current instance:  315 Num unsat clauses instance:  0
# Current instance:  316 Num unsat clauses instance:  0
# Current instance:  317 Num unsat clauses instance:  0
# Current instance:  318 Num unsat clauses instance:  0
# Current instance:  319 Num unsat clauses instance:  0
# Current instance:  320 Num unsat clauses instance:  0
# Current instance:  321 Num unsat clauses instance:  1
# Current instance:  322 Num unsat clauses instance:  0
# Current instance:  323 Num unsat clauses instance:  0
# Current instance:  324 Num unsat clauses instance:  0
# Current instance:  325 Num unsat clauses instance:  0
# Current instance:  326 Num unsat clauses instance:  0
# Current instance:  327 Num unsat clauses instance:  0
# Current instance:  328 Num unsat clauses instance:  0
# Current instance:  329 Num unsat clauses instance:  0
# Current instance:  330 Num unsat clauses instance:  0
# Current instance:  331 Num unsat clauses instance:  0
# Current instance:  332 Num unsat clauses instance:  0
# Current instance:  333 Num unsat clauses instance:  0
# Current instance:  334 Num unsat clauses instance:  0
# Current instance:  335 Num unsat clauses instance:  0
# Current instance:  336 Num unsat clauses instance:  0
# Current instance:  337 Num unsat clauses instance:  1
# Current instance:  338 Num unsat clauses instance:  0
# Current instance:  339 Num unsat clauses instance:  1
# Current instance:  340 Num unsat clauses instance:  0
# Current instance:  341 Num unsat clauses instance:  0
# Current instance:  342 Num unsat clauses instance:  0
# Current instance:  343 Num unsat clauses instance:  0
# Current instance:  344 Num unsat clauses instance:  0
# Current instance:  345 Num unsat clauses instance:  0
# Current instance:  346 Num unsat clauses instance:  0
# Current instance:  347 Num unsat clauses instance:  0
# Current instance:  348 Num unsat clauses instance:  1
# Current instance:  349 Num unsat clauses instance:  0
# Current instance:  350 Num unsat clauses instance:  0
# Current instance:  351 Num unsat clauses instance:  0
# Current instance:  352 Num unsat clauses instance:  0
# Current instance:  353 Num unsat clauses instance:  0
# Current instance:  354 Num unsat clauses instance:  0
# Current instance:  355 Num unsat clauses instance:  0
# Current instance:  356 Num unsat clauses instance:  0
# Current instance:  357 Num unsat clauses instance:  0
# Current instance:  358 Num unsat clauses instance:  1
# Current instance:  359 Num unsat clauses instance:  0
# Current instance:  360 Num unsat clauses instance:  1
# Current instance:  361 Num unsat clauses instance:  0
# Current instance:  362 Num unsat clauses instance:  0
# Current instance:  363 Num unsat clauses instance:  0
# Current instance:  364 Num unsat clauses instance:  0
# Current instance:  365 Num unsat clauses instance:  0
# Current instance:  366 Num unsat clauses instance:  0
# Current instance:  367 Num unsat clauses instance:  0
# Current instance:  368 Num unsat clauses instance:  0
# Current instance:  369 Num unsat clauses instance:  0
# Current instance:  370 Num unsat clauses instance:  0
# Current instance:  371 Num unsat clauses instance:  0
# Current instance:  372 Num unsat clauses instance:  0
# Current instance:  373 Num unsat clauses instance:  0
# Current instance:  374 Num unsat clauses instance:  0
# Current instance:  375 Num unsat clauses instance:  1
# Current instance:  376 Num unsat clauses instance:  0
# Current instance:  377 Num unsat clauses instance:  0
# Current instance:  378 Num unsat clauses instance:  0
# Current instance:  379 Num unsat clauses instance:  0
# Current instance:  380 Num unsat clauses instance:  0
# Current instance:  381 Num unsat clauses instance:  1
# Current instance:  382 Num unsat clauses instance:  1
# Current instance:  383 Num unsat clauses instance:  0
# Current instance:  384 Num unsat clauses instance:  0
# Current instance:  385 Num unsat clauses instance:  0
# Current instance:  386 Num unsat clauses instance:  0
# Current instance:  387 Num unsat clauses instance:  0
# Current instance:  388 Num unsat clauses instance:  0
# Current instance:  389 Num unsat clauses instance:  0
# Current instance:  390 Num unsat clauses instance:  0
# Current instance:  391 Num unsat clauses instance:  0
# Current instance:  392 Num unsat clauses instance:  1
# Current instance:  393 Num unsat clauses instance:  0
# Current instance:  394 Num unsat clauses instance:  0
# Current instance:  395 Num unsat clauses instance:  0
# Current instance:  396 Num unsat clauses instance:  0
# Current instance:  397 Num unsat clauses instance:  0
# Current instance:  398 Num unsat clauses instance:  1
# Current instance:  399 Num unsat clauses instance:  0
# Current instance:  400 Num unsat clauses instance:  0
# Current instance:  401 Num unsat clauses instance:  1
# Current instance:  402 Num unsat clauses instance:  0
# Current instance:  403 Num unsat clauses instance:  0
# Current instance:  404 Num unsat clauses instance:  0
# Current instance:  405 Num unsat clauses instance:  0
# Current instance:  406 Num unsat clauses instance:  0
# Current instance:  407 Num unsat clauses instance:  0
# Current instance:  408 Num unsat clauses instance:  0
# Current instance:  409 Num unsat clauses instance:  0
# Current instance:  410 Num unsat clauses instance:  0
# Current instance:  411 Num unsat clauses instance:  0
# Current instance:  412 Num unsat clauses instance:  0
# Current instance:  413 Num unsat clauses instance:  0
# Current instance:  414 Num unsat clauses instance:  0
# Current instance:  415 Num unsat clauses instance:  0
# Current instance:  416 Num unsat clauses instance:  1
# Current instance:  417 Num unsat clauses instance:  0
# Current instance:  418 Num unsat clauses instance:  0
# Current instance:  419 Num unsat clauses instance:  0
# Current instance:  420 Num unsat clauses instance:  1
# Current instance:  421 Num unsat clauses instance:  1
# Current instance:  422 Num unsat clauses instance:  0
# Current instance:  423 Num unsat clauses instance:  0
# Current instance:  424 Num unsat clauses instance:  0
# Current instance:  425 Num unsat clauses instance:  0
# Current instance:  426 Num unsat clauses instance:  0
# Current instance:  427 Num unsat clauses instance:  0
# Current instance:  428 Num unsat clauses instance:  0
# Current instance:  429 Num unsat clauses instance:  0
# Current instance:  430 Num unsat clauses instance:  1
# Current instance:  431 Num unsat clauses instance:  0
# Current instance:  432 Num unsat clauses instance:  0
# Current instance:  433 Num unsat clauses instance:  0
# Current instance:  434 Num unsat clauses instance:  0
# Current instance:  435 Num unsat clauses instance:  0
# Current instance:  436 Num unsat clauses instance:  0
# Current instance:  437 Num unsat clauses instance:  0
# Current instance:  438 Num unsat clauses instance:  0
# Current instance:  439 Num unsat clauses instance:  0
# Current instance:  440 Num unsat clauses instance:  0
# Current instance:  441 Num unsat clauses instance:  0
# Current instance:  442 Num unsat clauses instance:  0
# Current instance:  443 Num unsat clauses instance:  0
# Current instance:  444 Num unsat clauses instance:  0
# Current instance:  445 Num unsat clauses instance:  0
# Current instance:  446 Num unsat clauses instance:  0
# Current instance:  447 Num unsat clauses instance:  0
# Current instance:  448 Num unsat clauses instance:  1
# Current instance:  449 Num unsat clauses instance:  0
# Current instance:  450 Num unsat clauses instance:  0
# Current instance:  451 Num unsat clauses instance:  0
# Current instance:  452 Num unsat clauses instance:  0
# Current instance:  453 Num unsat clauses instance:  0
# Current instance:  454 Num unsat clauses instance:  1
# Current instance:  455 Num unsat clauses instance:  0
# Current instance:  456 Num unsat clauses instance:  0
# Current instance:  457 Num unsat clauses instance:  1
# Current instance:  458 Num unsat clauses instance:  1
# Current instance:  459 Num unsat clauses instance:  0
# Current instance:  460 Num unsat clauses instance:  0
# Current instance:  461 Num unsat clauses instance:  0
# Current instance:  462 Num unsat clauses instance:  0
# Current instance:  463 Num unsat clauses instance:  0
# Current instance:  464 Num unsat clauses instance:  0
# Current instance:  465 Num unsat clauses instance:  1
# Current instance:  466 Num unsat clauses instance:  0
# Current instance:  467 Num unsat clauses instance:  0
# Current instance:  468 Num unsat clauses instance:  0
# Current instance:  469 Num unsat clauses instance:  0
# Current instance:  470 Num unsat clauses instance:  0
# Current instance:  471 Num unsat clauses instance:  0
# Current instance:  472 Num unsat clauses instance:  1
# Current instance:  473 Num unsat clauses instance:  0
# Current instance:  474 Num unsat clauses instance:  0
# Current instance:  475 Num unsat clauses instance:  0
# Current instance:  476 Num unsat clauses instance:  0
# Current instance:  477 Num unsat clauses instance:  0
# Current instance:  478 Num unsat clauses instance:  0
# Current instance:  479 Num unsat clauses instance:  0
# Current instance:  480 Num unsat clauses instance:  0
# Current instance:  481 Num unsat clauses instance:  1
# Current instance:  482 Num unsat clauses instance:  0
# Current instance:  483 Num unsat clauses instance:  0
# Current instance:  484 Num unsat clauses instance:  0
# Current instance:  485 Num unsat clauses instance:  0
# Current instance:  486 Num unsat clauses instance:  0
# Current instance:  487 Num unsat clauses instance:  0
# Current instance:  488 Num unsat clauses instance:  0
# Current instance:  489 Num unsat clauses instance:  1
# Current instance:  490 Num unsat clauses instance:  0
# Current instance:  491 Num unsat clauses instance:  0
# Current instance:  492 Num unsat clauses instance:  0
# Current instance:  493 Num unsat clauses instance:  0
# Current instance:  494 Num unsat clauses instance:  0
# Current instance:  495 Num unsat clauses instance:  0
# Current instance:  496 Num unsat clauses instance:  1
# Current instance:  497 Num unsat clauses instance:  1
# Current instance:  498 Num unsat clauses instance:  1
# Current instance:  499 Num unsat clauses instance:  0
# Current instance:  500 Num unsat clauses instance:  0
# Current instance:  501 Num unsat clauses instance:  0
# Current instance:  502 Num unsat clauses instance:  0
# Current instance:  503 Num unsat clauses instance:  0
# Current instance:  504 Num unsat clauses instance:  0
# Current instance:  505 Num unsat clauses instance:  0
# Current instance:  506 Num unsat clauses instance:  0
# Current instance:  507 Num unsat clauses instance:  0
# Current instance:  508 Num unsat clauses instance:  0
# Current instance:  509 Num unsat clauses instance:  0
# Current instance:  510 Num unsat clauses instance:  0
# Current instance:  511 Num unsat clauses instance:  0
# Current instance:  512 Num unsat clauses instance:  0
# Current instance:  513 Num unsat clauses instance:  0
# Current instance:  514 Num unsat clauses instance:  0
# Current instance:  515 Num unsat clauses instance:  0
# Current instance:  516 Num unsat clauses instance:  0
# Current instance:  517 Num unsat clauses instance:  0
# Current instance:  518 Num unsat clauses instance:  0
# Current instance:  519 Num unsat clauses instance:  0
# Current instance:  520 Num unsat clauses instance:  0
# Current instance:  521 Num unsat clauses instance:  0
# Current instance:  522 Num unsat clauses instance:  0
# Current instance:  523 Num unsat clauses instance:  0
# Current instance:  524 Num unsat clauses instance:  0
# Current instance:  525 Num unsat clauses instance:  1
# Current instance:  526 Num unsat clauses instance:  0
# Current instance:  527 Num unsat clauses instance:  0
# Current instance:  528 Num unsat clauses instance:  0
# Current instance:  529 Num unsat clauses instance:  2
# Current instance:  530 Num unsat clauses instance:  0
# Current instance:  531 Num unsat clauses instance:  0
# Current instance:  532 Num unsat clauses instance:  1
# Current instance:  533 Num unsat clauses instance:  0
# Current instance:  534 Num unsat clauses instance:  0
# Current instance:  535 Num unsat clauses instance:  1
# Current instance:  536 Num unsat clauses instance:  0
# Current instance:  537 Num unsat clauses instance:  0
# Current instance:  538 Num unsat clauses instance:  0
# Current instance:  539 Num unsat clauses instance:  0
# Current instance:  540 Num unsat clauses instance:  1
# Current instance:  541 Num unsat clauses instance:  0
# Current instance:  542 Num unsat clauses instance:  0
# Current instance:  543 Num unsat clauses instance:  0
# Current instance:  544 Num unsat clauses instance:  0
# Current instance:  545 Num unsat clauses instance:  1
# Current instance:  546 Num unsat clauses instance:  1
# Current instance:  547 Num unsat clauses instance:  0
# Current instance:  548 Num unsat clauses instance:  0
# Current instance:  549 Num unsat clauses instance:  1
# Current instance:  550 Num unsat clauses instance:  0
# Current instance:  551 Num unsat clauses instance:  0
# Current instance:  552 Num unsat clauses instance:  0
# Current instance:  553 Num unsat clauses instance:  0
# Current instance:  554 Num unsat clauses instance:  0
# Current instance:  555 Num unsat clauses instance:  0
# Current instance:  556 Num unsat clauses instance:  0
# Current instance:  557 Num unsat clauses instance:  0
# Current instance:  558 Num unsat clauses instance:  1
# Current instance:  559 Num unsat clauses instance:  0
# Current instance:  560 Num unsat clauses instance:  1
# Current instance:  561 Num unsat clauses instance:  1
# Current instance:  562 Num unsat clauses instance:  0
# Current instance:  563 Num unsat clauses instance:  0
# Current instance:  564 Num unsat clauses instance:  0
# Current instance:  565 Num unsat clauses instance:  0
# Current instance:  566 Num unsat clauses instance:  0
# Current instance:  567 Num unsat clauses instance:  1
# Current instance:  568 Num unsat clauses instance:  0
# Current instance:  569 Num unsat clauses instance:  1
# Current instance:  570 Num unsat clauses instance:  1
# Current instance:  571 Num unsat clauses instance:  1
# Current instance:  572 Num unsat clauses instance:  0
# Current instance:  573 Num unsat clauses instance:  0
# Current instance:  574 Num unsat clauses instance:  1
# Current instance:  575 Num unsat clauses instance:  0
# Current instance:  576 Num unsat clauses instance:  0
# Current instance:  577 Num unsat clauses instance:  0
# Current instance:  578 Num unsat clauses instance:  1
# Current instance:  579 Num unsat clauses instance:  0
# Current instance:  580 Num unsat clauses instance:  0
# Current instance:  581 Num unsat clauses instance:  0
# Current instance:  582 Num unsat clauses instance:  0
# Current instance:  583 Num unsat clauses instance:  0
# Current instance:  584 Num unsat clauses instance:  0
# Current instance:  585 Num unsat clauses instance:  0
# Current instance:  586 Num unsat clauses instance:  0
# Current instance:  587 Num unsat clauses instance:  0
# Current instance:  588 Num unsat clauses instance:  0
# Current instance:  589 Num unsat clauses instance:  0
# Current instance:  590 Num unsat clauses instance:  0
# Current instance:  591 Num unsat clauses instance:  1
# Current instance:  592 Num unsat clauses instance:  0
# Current instance:  593 Num unsat clauses instance:  0
# Current instance:  594 Num unsat clauses instance:  1
# Current instance:  595 Num unsat clauses instance:  0
# Current instance:  596 Num unsat clauses instance:  0
# Current instance:  597 Num unsat clauses instance:  0
# Current instance:  598 Num unsat clauses instance:  0
# Current instance:  599 Num unsat clauses instance:  0
# Current instance:  600 Num unsat clauses instance:  0
# Current instance:  601 Num unsat clauses instance:  0
# Current instance:  602 Num unsat clauses instance:  0
# Current instance:  603 Num unsat clauses instance:  0
# Current instance:  604 Num unsat clauses instance:  0
# Current instance:  605 Num unsat clauses instance:  0
# Current instance:  606 Num unsat clauses instance:  1
# Current instance:  607 Num unsat clauses instance:  0
# Current instance:  608 Num unsat clauses instance:  0
# Current instance:  609 Num unsat clauses instance:  0
# Current instance:  610 Num unsat clauses instance:  0
# Current instance:  611 Num unsat clauses instance:  0
# Current instance:  612 Num unsat clauses instance:  0
# Current instance:  613 Num unsat clauses instance:  0
# Current instance:  614 Num unsat clauses instance:  0
# Current instance:  615 Num unsat clauses instance:  0
# Current instance:  616 Num unsat clauses instance:  0
# Current instance:  617 Num unsat clauses instance:  1
# Current instance:  618 Num unsat clauses instance:  0
# Current instance:  619 Num unsat clauses instance:  0
# Current instance:  620 Num unsat clauses instance:  1
# Current instance:  621 Num unsat clauses instance:  0
# Current instance:  622 Num unsat clauses instance:  0
# Current instance:  623 Num unsat clauses instance:  0
# Current instance:  624 Num unsat clauses instance:  0
# Current instance:  625 Num unsat clauses instance:  1
# Current instance:  626 Num unsat clauses instance:  0
# Current instance:  627 Num unsat clauses instance:  1
# Current instance:  628 Num unsat clauses instance:  0
# Current instance:  629 Num unsat clauses instance:  0
# Current instance:  630 Num unsat clauses instance:  0
# Current instance:  631 Num unsat clauses instance:  0
# Current instance:  632 Num unsat clauses instance:  0
# Current instance:  633 Num unsat clauses instance:  1
# Current instance:  634 Num unsat clauses instance:  1
# Current instance:  635 Num unsat clauses instance:  0
# Current instance:  636 Num unsat clauses instance:  0
# Current instance:  637 Num unsat clauses instance:  0
# Current instance:  638 Num unsat clauses instance:  0
# Current instance:  639 Num unsat clauses instance:  0
# Current instance:  640 Num unsat clauses instance:  0
# Current instance:  641 Num unsat clauses instance:  0
# Current instance:  642 Num unsat clauses instance:  0
# Current instance:  643 Num unsat clauses instance:  0
# Current instance:  644 Num unsat clauses instance:  1
# Current instance:  645 Num unsat clauses instance:  0
# Current instance:  646 Num unsat clauses instance:  0
# Current instance:  647 Num unsat clauses instance:  1
# Current instance:  648 Num unsat clauses instance:  0
# Current instance:  649 Num unsat clauses instance:  0
# Current instance:  650 Num unsat clauses instance:  0
# Current instance:  651 Num unsat clauses instance:  0
# Current instance:  652 Num unsat clauses instance:  1
# Current instance:  653 Num unsat clauses instance:  1
# Current instance:  654 Num unsat clauses instance:  0
# Current instance:  655 Num unsat clauses instance:  0
# Current instance:  656 Num unsat clauses instance:  0
# Current instance:  657 Num unsat clauses instance:  0
# Current instance:  658 Num unsat clauses instance:  0
# Current instance:  659 Num unsat clauses instance:  0
# Current instance:  660 Num unsat clauses instance:  0
# Current instance:  661 Num unsat clauses instance:  1
# Current instance:  662 Num unsat clauses instance:  0
# Current instance:  663 Num unsat clauses instance:  0
# Current instance:  664 Num unsat clauses instance:  0
# Current instance:  665 Num unsat clauses instance:  0
# Current instance:  666 Num unsat clauses instance:  0
# Current instance:  667 Num unsat clauses instance:  1
# Current instance:  668 Num unsat clauses instance:  0
# Current instance:  669 Num unsat clauses instance:  0
# Current instance:  670 Num unsat clauses instance:  0
# Current instance:  671 Num unsat clauses instance:  0
# Current instance:  672 Num unsat clauses instance:  0
# Current instance:  673 Num unsat clauses instance:  0
# Current instance:  674 Num unsat clauses instance:  1
# Current instance:  675 Num unsat clauses instance:  0
# Current instance:  676 Num unsat clauses instance:  0
# Current instance:  677 Num unsat clauses instance:  0
# Current instance:  678 Num unsat clauses instance:  0
# Current instance:  679 Num unsat clauses instance:  0
# Current instance:  680 Num unsat clauses instance:  0
# Current instance:  681 Num unsat clauses instance:  1
# Current instance:  682 Num unsat clauses instance:  0
# Current instance:  683 Num unsat clauses instance:  0
# Current instance:  684 Num unsat clauses instance:  0
# Current instance:  685 Num unsat clauses instance:  0
# Current instance:  686 Num unsat clauses instance:  0
# Current instance:  687 Num unsat clauses instance:  0
# Current instance:  688 Num unsat clauses instance:  0
# Current instance:  689 Num unsat clauses instance:  0
# Current instance:  690 Num unsat clauses instance:  0
# Current instance:  691 Num unsat clauses instance:  0
# Current instance:  692 Num unsat clauses instance:  0
# Current instance:  693 Num unsat clauses instance:  0
# Current instance:  694 Num unsat clauses instance:  0
# Current instance:  695 Num unsat clauses instance:  0
# Current instance:  696 Num unsat clauses instance:  0
# Current instance:  697 Num unsat clauses instance:  0
# Current instance:  698 Num unsat clauses instance:  0
# Current instance:  699 Num unsat clauses instance:  0
# Current instance:  700 Num unsat clauses instance:  0
# Current instance:  701 Num unsat clauses instance:  0
# Current instance:  702 Num unsat clauses instance:  0
# Current instance:  703 Num unsat clauses instance:  0
# Current instance:  704 Num unsat clauses instance:  0
# Current instance:  705 Num unsat clauses instance:  0
# Current instance:  706 Num unsat clauses instance:  0
# Current instance:  707 Num unsat clauses instance:  0
# Current instance:  708 Num unsat clauses instance:  1
# Current instance:  709 Num unsat clauses instance:  0
# Current instance:  710 Num unsat clauses instance:  0
# Current instance:  711 Num unsat clauses instance:  0
# Current instance:  712 Num unsat clauses instance:  0
# Current instance:  713 Num unsat clauses instance:  0
# Current instance:  714 Num unsat clauses instance:  0
# Current instance:  715 Num unsat clauses instance:  0
# Current instance:  716 Num unsat clauses instance:  0
# Current instance:  717 Num unsat clauses instance:  0
# Current instance:  718 Num unsat clauses instance:  0
# Current instance:  719 Num unsat clauses instance:  0
# Current instance:  720 Num unsat clauses instance:  0
# Current instance:  721 Num unsat clauses instance:  0
# Current instance:  722 Num unsat clauses instance:  0
# Current instance:  723 Num unsat clauses instance:  0
# Current instance:  724 Num unsat clauses instance:  1
# Current instance:  725 Num unsat clauses instance:  0
# Current instance:  726 Num unsat clauses instance:  0
# Current instance:  727 Num unsat clauses instance:  1
# Current instance:  728 Num unsat clauses instance:  0
# Current instance:  729 Num unsat clauses instance:  0
# Current instance:  730 Num unsat clauses instance:  0
# Current instance:  731 Num unsat clauses instance:  0
# Current instance:  732 Num unsat clauses instance:  0
# Current instance:  733 Num unsat clauses instance:  0
# Current instance:  734 Num unsat clauses instance:  0
# Current instance:  735 Num unsat clauses instance:  1
# Current instance:  736 Num unsat clauses instance:  0
# Current instance:  737 Num unsat clauses instance:  0
# Current instance:  738 Num unsat clauses instance:  1
# Current instance:  739 Num unsat clauses instance:  0
# Current instance:  740 Num unsat clauses instance:  0
# Current instance:  741 Num unsat clauses instance:  0
# Current instance:  742 Num unsat clauses instance:  0
# Current instance:  743 Num unsat clauses instance:  0
# Current instance:  744 Num unsat clauses instance:  1
# Current instance:  745 Num unsat clauses instance:  1
# Current instance:  746 Num unsat clauses instance:  0
# Current instance:  747 Num unsat clauses instance:  1
# Current instance:  748 Num unsat clauses instance:  0
# Current instance:  749 Num unsat clauses instance:  0
# Current instance:  750 Num unsat clauses instance:  0
# Current instance:  751 Num unsat clauses instance:  1
# Current instance:  752 Num unsat clauses instance:  0
# Current instance:  753 Num unsat clauses instance:  0
# Current instance:  754 Num unsat clauses instance:  0
# Current instance:  755 Num unsat clauses instance:  0
# Current instance:  756 Num unsat clauses instance:  1
# Current instance:  757 Num unsat clauses instance:  0
# Current instance:  758 Num unsat clauses instance:  0
# Current instance:  759 Num unsat clauses instance:  0
# Current instance:  760 Num unsat clauses instance:  0
# Current instance:  761 Num unsat clauses instance:  0
# Current instance:  762 Num unsat clauses instance:  1
# Current instance:  763 Num unsat clauses instance:  0
# Current instance:  764 Num unsat clauses instance:  0
# Current instance:  765 Num unsat clauses instance:  1
# Current instance:  766 Num unsat clauses instance:  0
# Current instance:  767 Num unsat clauses instance:  0
# Current instance:  768 Num unsat clauses instance:  0
# Current instance:  769 Num unsat clauses instance:  0
# Current instance:  770 Num unsat clauses instance:  0
# Current instance:  771 Num unsat clauses instance:  1
# Current instance:  772 Num unsat clauses instance:  1
# Current instance:  773 Num unsat clauses instance:  0
# Current instance:  774 Num unsat clauses instance:  0
# Current instance:  775 Num unsat clauses instance:  0
# Current instance:  776 Num unsat clauses instance:  0
# Current instance:  777 Num unsat clauses instance:  1
# Current instance:  778 Num unsat clauses instance:  0
# Current instance:  779 Num unsat clauses instance:  0
# Current instance:  780 Num unsat clauses instance:  1
# Current instance:  781 Num unsat clauses instance:  0
# Current instance:  782 Num unsat clauses instance:  0
# Current instance:  783 Num unsat clauses instance:  0
# Current instance:  784 Num unsat clauses instance:  0
# Current instance:  785 Num unsat clauses instance:  0
# Current instance:  786 Num unsat clauses instance:  0
# Current instance:  787 Num unsat clauses instance:  0
# Current instance:  788 Num unsat clauses instance:  0
# Current instance:  789 Num unsat clauses instance:  1
# Current instance:  790 Num unsat clauses instance:  0
# Current instance:  791 Num unsat clauses instance:  0
# Current instance:  792 Num unsat clauses instance:  0
# Current instance:  793 Num unsat clauses instance:  0
# Current instance:  794 Num unsat clauses instance:  0
# Current instance:  795 Num unsat clauses instance:  0
# Current instance:  796 Num unsat clauses instance:  0
# Current instance:  797 Num unsat clauses instance:  0
# Current instance:  798 Num unsat clauses instance:  1
# Current instance:  799 Num unsat clauses instance:  0
# Current instance:  800 Num unsat clauses instance:  0
# Current instance:  801 Num unsat clauses instance:  0
# Current instance:  802 Num unsat clauses instance:  0
# Current instance:  803 Num unsat clauses instance:  0
# Current instance:  804 Num unsat clauses instance:  0
# Current instance:  805 Num unsat clauses instance:  0
# Current instance:  806 Num unsat clauses instance:  0
# Current instance:  807 Num unsat clauses instance:  0
# Current instance:  808 Num unsat clauses instance:  0
# Current instance:  809 Num unsat clauses instance:  1
# Current instance:  810 Num unsat clauses instance:  0
# Current instance:  811 Num unsat clauses instance:  0
# Current instance:  812 Num unsat clauses instance:  0
# Current instance:  813 Num unsat clauses instance:  0
# Current instance:  814 Num unsat clauses instance:  0
# Current instance:  815 Num unsat clauses instance:  0
# Current instance:  816 Num unsat clauses instance:  0
# Current instance:  817 Num unsat clauses instance:  0
# Current instance:  818 Num unsat clauses instance:  0
# Current instance:  819 Num unsat clauses instance:  0
# Current instance:  820 Num unsat clauses instance:  0
# Current instance:  821 Num unsat clauses instance:  0
# Current instance:  822 Num unsat clauses instance:  0
# Current instance:  823 Num unsat clauses instance:  0
# Current instance:  824 Num unsat clauses instance:  0
# Current instance:  825 Num unsat clauses instance:  0
# Current instance:  826 Num unsat clauses instance:  0
# Current instance:  827 Num unsat clauses instance:  0
# Current instance:  828 Num unsat clauses instance:  0
# Current instance:  829 Num unsat clauses instance:  0
# Current instance:  830 Num unsat clauses instance:  0
# Current instance:  831 Num unsat clauses instance:  0
# Current instance:  832 Num unsat clauses instance:  0
# Current instance:  833 Num unsat clauses instance:  0
# Current instance:  834 Num unsat clauses instance:  0
# Current instance:  835 Num unsat clauses instance:  0
# Current instance:  836 Num unsat clauses instance:  0
# Current instance:  837 Num unsat clauses instance:  0
# Current instance:  838 Num unsat clauses instance:  0
# Current instance:  839 Num unsat clauses instance:  0
# Current instance:  840 Num unsat clauses instance:  0
# Current instance:  841 Num unsat clauses instance:  1
# Current instance:  842 Num unsat clauses instance:  0
# Current instance:  843 Num unsat clauses instance:  0
# Current instance:  844 Num unsat clauses instance:  0
# Current instance:  845 Num unsat clauses instance:  0
# Current instance:  846 Num unsat clauses instance:  0
# Current instance:  847 Num unsat clauses instance:  0
# Current instance:  848 Num unsat clauses instance:  0
# Current instance:  849 Num unsat clauses instance:  0
# Current instance:  850 Num unsat clauses instance:  0
# Current instance:  851 Num unsat clauses instance:  0
# Current instance:  852 Num unsat clauses instance:  0
# Current instance:  853 Num unsat clauses instance:  0
# Current instance:  854 Num unsat clauses instance:  0
# Current instance:  855 Num unsat clauses instance:  0
# Current instance:  856 Num unsat clauses instance:  0
# Current instance:  857 Num unsat clauses instance:  0
# Current instance:  858 Num unsat clauses instance:  1
# Current instance:  859 Num unsat clauses instance:  0
# Current instance:  860 Num unsat clauses instance:  0
# Current instance:  861 Num unsat clauses instance:  0
# Current instance:  862 Num unsat clauses instance:  0
# Current instance:  863 Num unsat clauses instance:  0
# Current instance:  864 Num unsat clauses instance:  0
# Current instance:  865 Num unsat clauses instance:  0
# Current instance:  866 Num unsat clauses instance:  1
# Current instance:  867 Num unsat clauses instance:  2
# Current instance:  868 Num unsat clauses instance:  1
# Current instance:  869 Num unsat clauses instance:  0
# Current instance:  870 Num unsat clauses instance:  0
# Current instance:  871 Num unsat clauses instance:  0
# Current instance:  872 Num unsat clauses instance:  0
# Current instance:  873 Num unsat clauses instance:  0
# Current instance:  874 Num unsat clauses instance:  0
# Current instance:  875 Num unsat clauses instance:  0
# Current instance:  876 Num unsat clauses instance:  0
# Current instance:  877 Num unsat clauses instance:  0
# Current instance:  878 Num unsat clauses instance:  0
# Current instance:  879 Num unsat clauses instance:  0
# Current instance:  880 Num unsat clauses instance:  0
# Current instance:  881 Num unsat clauses instance:  0
# Current instance:  882 Num unsat clauses instance:  0
# Current instance:  883 Num unsat clauses instance:  0
# Current instance:  884 Num unsat clauses instance:  0
# Current instance:  885 Num unsat clauses instance:  1
# Current instance:  886 Num unsat clauses instance:  0
# Current instance:  887 Num unsat clauses instance:  0
# Current instance:  888 Num unsat clauses instance:  0
# Current instance:  889 Num unsat clauses instance:  1
# Current instance:  890 Num unsat clauses instance:  0
# Current instance:  891 Num unsat clauses instance:  0
# Current instance:  892 Num unsat clauses instance:  0
# Current instance:  893 Num unsat clauses instance:  0
# Current instance:  894 Num unsat clauses instance:  0
# Current instance:  895 Num unsat clauses instance:  0
# Current instance:  896 Num unsat clauses instance:  0
# Current instance:  897 Num unsat clauses instance:  0
# Current instance:  898 Num unsat clauses instance:  0
# Current instance:  899 Num unsat clauses instance:  0
# Current instance:  900 Num unsat clauses instance:  0
# Current instance:  901 Num unsat clauses instance:  0
# Current instance:  902 Num unsat clauses instance:  0
# Current instance:  903 Num unsat clauses instance:  1
# Current instance:  904 Num unsat clauses instance:  0
# Current instance:  905 Num unsat clauses instance:  0
# Current instance:  906 Num unsat clauses instance:  0
# Current instance:  907 Num unsat clauses instance:  0
# Current instance:  908 Num unsat clauses instance:  0
# Current instance:  909 Num unsat clauses instance:  0
# Current instance:  910 Num unsat clauses instance:  0
# Current instance:  911 Num unsat clauses instance:  0
# Current instance:  912 Num unsat clauses instance:  0
# Current instance:  913 Num unsat clauses instance:  0
# Current instance:  914 Num unsat clauses instance:  0
# Current instance:  915 Num unsat clauses instance:  0
# Current instance:  916 Num unsat clauses instance:  0
# Current instance:  917 Num unsat clauses instance:  0
# Current instance:  918 Num unsat clauses instance:  0
# Current instance:  919 Num unsat clauses instance:  0
# Current instance:  920 Num unsat clauses instance:  0
# Current instance:  921 Num unsat clauses instance:  0
# Current instance:  922 Num unsat clauses instance:  0
# Current instance:  923 Num unsat clauses instance:  0
# Current instance:  924 Num unsat clauses instance:  0
# Current instance:  925 Num unsat clauses instance:  0
# Current instance:  926 Num unsat clauses instance:  0
# Current instance:  927 Num unsat clauses instance:  0
# Current instance:  928 Num unsat clauses instance:  0
# Current instance:  929 Num unsat clauses instance:  1
# Current instance:  930 Num unsat clauses instance:  0
# Current instance:  931 Num unsat clauses instance:  0
# Current instance:  932 Num unsat clauses instance:  0
# Current instance:  933 Num unsat clauses instance:  1
# Current instance:  934 Num unsat clauses instance:  0
# Current instance:  935 Num unsat clauses instance:  0
# Current instance:  936 Num unsat clauses instance:  0
# Current instance:  937 Num unsat clauses instance:  0
# Current instance:  938 Num unsat clauses instance:  0
# Current instance:  939 Num unsat clauses instance:  0
# Current instance:  940 Num unsat clauses instance:  0
# Current instance:  941 Num unsat clauses instance:  0
# Current instance:  942 Num unsat clauses instance:  0
# Current instance:  943 Num unsat clauses instance:  0
# Current instance:  944 Num unsat clauses instance:  1
# Current instance:  945 Num unsat clauses instance:  0
# Current instance:  946 Num unsat clauses instance:  0
# Current instance:  947 Num unsat clauses instance:  0
# Current instance:  948 Num unsat clauses instance:  0
# Current instance:  949 Num unsat clauses instance:  1
# Current instance:  950 Num unsat clauses instance:  0
# Current instance:  951 Num unsat clauses instance:  0
# Current instance:  952 Num unsat clauses instance:  0
# Current instance:  953 Num unsat clauses instance:  0
# Current instance:  954 Num unsat clauses instance:  1
# Current instance:  955 Num unsat clauses instance:  0
# Current instance:  956 Num unsat clauses instance:  0
# Current instance:  957 Num unsat clauses instance:  0
# Current instance:  958 Num unsat clauses instance:  0
# Current instance:  959 Num unsat clauses instance:  0
# Current instance:  960 Num unsat clauses instance:  0
# Current instance:  961 Num unsat clauses instance:  0
# Current instance:  962 Num unsat clauses instance:  0
# Current instance:  963 Num unsat clauses instance:  0
# Current instance:  964 Num unsat clauses instance:  0
# Current instance:  965 Num unsat clauses instance:  0
# Current instance:  966 Num unsat clauses instance:  0
# Current instance:  967 Num unsat clauses instance:  0
# Current instance:  968 Num unsat clauses instance:  0
# Current instance:  969 Num unsat clauses instance:  0
# Current instance:  970 Num unsat clauses instance:  0
# Current instance:  971 Num unsat clauses instance:  0
# Current instance:  972 Num unsat clauses instance:  0
# Current instance:  973 Num unsat clauses instance:  0
# Current instance:  974 Num unsat clauses instance:  0
# Current instance:  975 Num unsat clauses instance:  0
# Current instance:  976 Num unsat clauses instance:  0
# Current instance:  977 Num unsat clauses instance:  0
# Current instance:  978 Num unsat clauses instance:  0
# Current instance:  979 Num unsat clauses instance:  1
# Current instance:  980 Num unsat clauses instance:  0
# Current instance:  981 Num unsat clauses instance:  0
# Current instance:  982 Num unsat clauses instance:  1
# Current instance:  983 Num unsat clauses instance:  0
# Current instance:  984 Num unsat clauses instance:  0
# Current instance:  985 Num unsat clauses instance:  0
# Current instance:  986 Num unsat clauses instance:  0
# Current instance:  987 Num unsat clauses instance:  0
# Current instance:  988 Num unsat clauses instance:  1
# Current instance:  989 Num unsat clauses instance:  0
# Current instance:  990 Num unsat clauses instance:  0
# Current instance:  991 Num unsat clauses instance:  0
# Current instance:  992 Num unsat clauses instance:  0
# Current instance:  993 Num unsat clauses instance:  0
# Current instance:  994 Num unsat clauses instance:  0
# Current instance:  995 Num unsat clauses instance:  0
# Current instance:  996 Num unsat clauses instance:  0
# Current instance:  997 Num unsat clauses instance:  0
# Current instance:  998 Num unsat clauses instance:  0
# Current instance:  999 Num unsat clauses instance:  0
# Current instance:  1000 Num unsat clauses instance:  0

# %% [markdown]
# ## Sanity check: check number of unsat clauses after running walksat. This number should obviously not be 0 for unsat instances.

# %%
for key in file_scores.keys():
    if file_scores[key][0]==0:
        #print(file_scores[key][1])
        if file_scores[key][1]==file_scores[key][0]:
            print("Error: Walksat finds somehow a 0 unsat clause assignment on an unsat formula.")

# %% [markdown]
# ## Print walksat results

# %%
print("Average number of unsat clauses by Walksat on the test instances: ", sum(num_unsatclauses_perinstance)/len(num_unsatclauses_perinstance))
# Out:
# Average number of unsat clauses by Walksat on the test instances:  0.146
